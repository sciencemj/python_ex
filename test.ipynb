# %%
puzzel = [4,3,0,
          1,2,6,
          5,7,8]

goal = [1,2,3,
        4,5,6,
        7,8,0]
class PuzzelMap:
    def __init__(self, map, age, parent):
        self.age = age
        self.goal = [1,2,3,
                     4,5,6,
                     7,8,0]
        self.map = map
        self.parent = parent

    def find_dir(self):
        for i in self.map:
            if i == 0:
                index = self.map.index(i)
                if index == 0:
                    return [1,3]
                elif index == 1:
                    return [-1,1,3]
                elif index == 2:
                    return [-1,3]
                elif index == 3:
                    return [-3,1,3]
                elif index == 4:
                    return [-3,-1,1,3]
                elif index == 5:
                    return [-3,-1,3]
                elif index == 6:
                    return [-3,1]
                elif index == 7:
                    return [-3,-1,1]
                elif index == 8:
                    return [-3,-1]

    def move(self):
        index = self.map.index(0)
        child_node = []
        for dir in self.find_dir():
            map_ = list(self.map)
            map_[index] = map_[index + dir]
            map_[index + dir] = 0
            child_node.insert(0, PuzzelMap(map_, self.age + 1, self))
        return child_node
                
def print_map(map):
    print("", map[0], map[1], map[2], "\n"
        , map[3], map[4], map[5], "\n"
        , map[6] , map[7] , map[8], "\n", "")

# %% [markdown]
# DFS(깊이 우선 탐색)

# %%
open = [PuzzelMap(puzzel, 0, None)]

closed = []

printer = []

while len(open) != 0:
    map = open.pop()
    closed.append(map.map)
    #print(map.map)
    if map.age < 100:
        child = map.move()
        for i in child:
            if not i.map in closed:
                if i.map == goal:
                    print("end!")
                    printer.insert(0, i.map)
                    p = i.parent
                    while p != None:
                        printer.insert(0, p.map)
                        p = p.parent
                    for j in printer: print_map(j)
                    open.clear()
                    break
                open.insert(0, i)
# Out:
# end!
#  4 3 0
#  1 2 6
#  5 7 8
#
#  4 0 3
#  1 2 6
#  5 7 8
#
#  4 2 3
#  1 0 6
#  5 7 8
#
#  4 2 3
#  0 1 6
#  5 7 8
#
#  4 2 3
#  5 1 6
#  0 7 8
#
#  4 2 3
#  5 1 6
#  7 0 8
#
#  4 2 3
#  5 1 6
#  7 8 0
#
#  4 2 3
#  5 1 0
#  7 8 6
#
#  4 2 0
#  5 1 3
#  7 8 6
#
#  4 0 2
#  5 1 3
#  7 8 6
#
#  4 1 2
#  5 0 3
#  7 8 6
#
#  4 1 2
#  0 5 3
#  7 8 6
#
#  0 1 2
#  4 5 3
#  7 8 6
#
#  1 0 2
#  4 5 3
#  7 8 6
#
#  1 2 0
#  4 5 3
#  7 8 6
#
#  1 2 3
#  4 5 0
#  7 8 6
#
#  1 2 3
#  4 5 6
#  7 8 0

# %% [markdown]
# A*

# %%
def get_score(map, goal):
    total_score = 0
    for i in map:
        goal_i = goal.index(i)
        row = map.index(i) % 3
        column = map.index(i) // 3
        row_g = goal_i % 3
        column_g = goal_i // 3
        total_score += abs(row - row_g) + abs(column - column_g)
    return total_score

# %%
puzzel = [1,2,0,
          4,5,3,
          7,8,6]

goal = [1,2,3,
        4,5,6,
        7,8,0]

def get_score(map, goal):
    total_score = 0
    for i in map:
        goal_i = goal.index(i)
        row = map.index(i) % 3
        column = map.index(i) // 3
        row_g = goal_i % 3
        column_g = goal_i // 3
        total_score += abs(row - row_g) + abs(column - column_g)
    return total_score

class PuzzelMap:
    def __init__(self, map, age, parent):
        self.age = age
        self.goal = [1,2,3,
                     4,5,6,
                     7,8,0]
        self.map = map
        self.parent = parent
        self.score = age + get_score(map, self.goal)

    def find_dir(self):
        for i in self.map:
            if i == 0:
                index = self.map.index(i)
                if index == 0:
                    return [1,3]
                elif index == 1:
                    return [-1,1,3]
                elif index == 2:
                    return [-1,3]
                elif index == 3:
                    return [-3,1,3]
                elif index == 4:
                    return [-3,-1,1,3]
                elif index == 5:
                    return [-3,-1,3]
                elif index == 6:
                    return [-3,1]
                elif index == 7:
                    return [-3,-1,1]
                elif index == 8:
                    return [-3,-1]

    def move(self):
        index = self.map.index(0)
        child_node = []
        for dir in self.find_dir():
            map_ = list(self.map)
            map_[index] = map_[index + dir]
            map_[index + dir] = 0
            child_node.insert(0, PuzzelMap(map_, self.age + 1, self))
        return child_node
                
def print_map(map,score):
    print("", map[0], map[1], map[2], "\n"
        , map[3], map[4], map[5], "\n"
        , map[6] , map[7] , map[8], "\n", "score:", score)

open = [PuzzelMap(puzzel, 0, None)]

closed = []

printer = []

while len(open) != 0:
    open.sort(key=lambda p: p.score)
    #print(open)
    map = open.pop()
    closed.append(map.map)
    print_map(map.map, map.score)
    if map.age < 100:
        child = map.move()
        for i in child:
            if not i.map in closed:
                if i.map == goal:
                    print("end!")
                    printer.insert(0, i.map)
                    p = i.parent
                    while p != None:
                        printer.insert(0, p)
                        p = p.parent
                    for j in printer: print_map(j.map, j.score)
                    open.clear()
                    break
                open.insert(0, i)
# Out:
#  1 2 0
#  4 5 3
#  7 8 6
#
#  1 0 2
#  4 5 3
#  7 8 6
#
#  0 1 2
#  4 5 3
#  7 8 6
#
#  4 1 2
#  0 5 3
#  7 8 6
#
#  4 1 2
#  7 5 3
#  0 8 6
#
#  4 1 2
#  7 5 3
#  8 0 6
#
#  4 1 2
#  7 0 3
#  8 5 6
#
#  4 1 2
#  0 7 3
#  8 5 6
#
#  4 1 2
#  8 7 3
#  0 5 6
#
#  4 1 2
#  8 7 3
#  5 0 6
#
#  4 1 2
#  8 7 3
#  5 6 0
#
#  4 1 2
#  8 7 0
#  5 6 3
#
#  4 1 2
#  8 0 7
#  5 6 3
#
#  4 0 2
#  8 1 7
#  5 6 3
#
#  0 4 2
#  8 1 7
#  5 6 3
#
#  8 4 2
#  0 1 7
#  5 6 3
#
#  8 4 2
#  5 1 7
#  0 6 3
#
#  8 4 2
#  5 1 7
#  6 0 3
#
#  8 4 2
#  5 0 7
#  6 1 3
#
#  8 4 2
#  0 5 7
#  6 1 3
#
#  0 4 2
#  8 5 7
#  6 1 3
#
#  8 0 2
#  5 4 7
#  6 1 3
#
#  0 8 2
#  5 4 7
#  6 1 3
#
#  5 8 2
#  0 4 7
#  6 1 3
#
#  5 8 2
#  6 4 7
#  0 1 3
#
#  5 8 2
#  4 0 7
#  6 1 3
#
#  5 0 2
#  4 8 7
#  6 1 3
#
#  0 5 2
#  4 8 7
#  6 1 3
#
#  4 5 2
#  0 8 7
#  6 1 3
#
#  4 5 2
#  8 0 7
#  6 1 3
#
#  4 0 2
#  8 5 7
#  6 1 3
#
#  4 2 0
#  8 5 7
#  6 1 3
#
#  4 2 7
#  8 5 0
#  6 1 3
#
#  4 2 7
#  8 0 5
#  6 1 3
#
#  4 0 7
#  8 2 5
#  6 1 3
#
#  0 4 7
#  8 2 5
#  6 1 3
#
#  8 4 7
#  0 2 5
#  6 1 3
#
#  8 4 7
#  2 0 5
#  6 1 3
#
#  8 0 7
#  2 4 5
#  6 1 3
#
#  0 8 7
#  2 4 5
#  6 1 3
#
#  2 8 7
#  0 4 5
#  6 1 3
#
#  8 7 0
#  2 4 5
#  6 1 3
#
#  8 7 5
#  2 4 0
#  6 1 3
#
#  8 7 5
#  2 0 4
#  6 1 3
#
#  8 7 5
#  0 2 4
#  6 1 3
#
#  0 7 5
#  8 2 4
#  6 1 3
#
#  8 0 5
#  2 7 4
#  6 1 3
#
#  0 8 5
#  2 7 4
#  6 1 3
#
#  7 0 5
#  8 2 4
#  6 1 3
#
#  2 8 5
#  0 7 4
#  6 1 3
#
#  8 7 5
#  6 2 4
#  0 1 3
#
#  8 5 0
#  2 7 4
#  6 1 3
#
#  8 5 4
#  2 7 0
#  6 1 3
#
#  8 5 4
#  2 0 7
#  6 1 3
#
#  8 5 4
#  0 2 7
#  6 1 3
#
#  0 5 4
#  8 2 7
#  6 1 3
#
#  5 0 4
#  8 2 7
#  6 1 3
#
#  5 2 4
#  8 0 7
#  6 1 3
#
#  5 2 4
#  0 8 7
#  6 1 3
#
#  0 2 4
#  5 8 7
#  6 1 3
#
#  2 0 4
#  5 8 7
#  6 1 3
#
#  2 8 4
#  5 0 7
#  6 1 3
#
#  2 8 4
#  0 5 7
#  6 1 3
#
#  0 8 4
#  2 5 7
#  6 1 3
#
#  8 0 4
#  2 5 7
#  6 1 3
#
#  8 4 0
#  2 5 7
#  6 1 3
#
#  8 4 7
#  2 5 0
#  6 1 3
#
#  8 4 7
#  2 5 3
#  6 1 0
#
#  8 4 7
#  2 5 3
#  6 0 1
#
#  8 4 7
#  2 0 3
#  6 5 1
#
#  8 4 7
#  2 3 0
#  6 5 1
#
#  8 4 0
#  2 3 7
#  6 5 1
#
#  8 0 4
#  2 3 7
#  6 5 1
#
#  0 8 4
#  2 3 7
#  6 5 1
#
#  2 8 4
#  0 3 7
#  6 5 1
#
#  2 8 4
#  3 0 7
#  6 5 1
#
#  2 0 4
#  3 8 7
#  6 5 1
#
#  0 2 4
#  3 8 7
#  6 5 1
#
#  3 2 4
#  0 8 7
#  6 5 1
#
#  3 2 4
#  8 0 7
#  6 5 1
#
#  3 0 4
#  8 2 7
#  6 5 1
#
#  0 3 4
#  8 2 7
#  6 5 1
#
#  8 3 4
#  0 2 7
#  6 5 1
#
#  8 3 4
#  2 0 7
#  6 5 1
#
#  8 3 4
#  2 5 7
#  6 0 1
#
#  8 3 4
#  2 5 7
#  0 6 1
#
#  8 3 4
#  0 5 7
#  2 6 1
#
#  8 3 4
#  5 0 7
#  2 6 1
#
#  8 0 4
#  5 3 7
#  2 6 1
#
#  0 8 4
#  5 3 7
#  2 6 1
#
#  5 8 4
#  0 3 7
#  2 6 1
#
#  5 8 4
#  3 0 7
#  2 6 1
#
#  5 0 4
#  3 8 7
#  2 6 1
#
#  0 5 4
#  3 8 7
#  2 6 1
#
#  3 5 4
#  0 8 7
#  2 6 1
#
#  3 5 4
#  8 0 7
#  2 6 1
#
#  3 0 4
#  8 5 7
#  2 6 1
#
#  0 3 4
#  8 5 7
#  2 6 1
#
#  3 4 0
#  8 5 7
#  2 6 1
#
#  3 4 7
#  8 5 0
#  2 6 1
#
#  3 4 7
#  8 0 5
#  2 6 1
#
#  3 4 7
#  0 8 5
#  2 6 1
#
#  0 4 7
#  3 8 5
#  2 6 1
#
#  4 0 7
#  3 8 5
#  2 6 1
#
#  4 8 7
#  3 0 5
#  2 6 1
#
#  4 8 7
#  0 3 5
#  2 6 1
#
#  0 8 7
#  4 3 5
#  2 6 1
#
#  8 0 7
#  4 3 5
#  2 6 1
#
#  8 3 7
#  4 0 5
#  2 6 1
#
#  8 3 7
#  0 4 5
#  2 6 1
#
#  0 3 7
#  8 4 5
#  2 6 1
#
#  3 0 7
#  8 4 5
#  2 6 1
#
#  3 7 0
#  8 4 5
#  2 6 1
#
#  8 3 7
#  2 4 5
#  0 6 1
#
#  8 3 7
#  2 4 5
#  6 0 1
#
#  8 3 7
#  2 0 5
#  6 4 1
#
#  8 3 7
#  2 4 5
#  6 1 0
#
#  8 7 0
#  4 3 5
#  2 6 1
#
#  8 7 5
#  4 3 0
#  2 6 1
#
#  8 7 5
#  4 0 3
#  2 6 1
#
#  8 7 5
#  0 4 3
#  2 6 1
#
#  0 7 5
#  8 4 3
#  2 6 1
#
#  8 7 5
#  2 4 3
#  0 6 1
#
#  8 0 5
#  4 7 3
#  2 6 1
#
#  0 8 5
#  4 7 3
#  2 6 1
#
#  8 5 0
#  4 7 3
#  2 6 1
#
#  8 7 5
#  4 6 3
#  2 0 1
#
#  8 7 5
#  4 6 3
#  0 2 1
#
#  8 7 5
#  4 3 1
#  2 6 0
#
#  8 7 5
#  4 3 1
#  2 0 6
#
#  8 7 5
#  4 0 1
#  2 3 6
#
#  8 7 5
#  4 3 1
#  0 2 6
#
#  8 7 5
#  4 6 3
#  2 1 0
#
#  8 3 7
#  4 6 5
#  2 0 1
#
#  8 3 7
#  4 6 5
#  0 2 1
#
#  8 3 7
#  0 6 5
#  4 2 1
#
#  8 3 7
#  6 0 5
#  4 2 1
#
#  0 3 7
#  8 6 5
#  4 2 1
#
#  8 3 7
#  4 5 0
#  2 6 1
#
#  8 3 0
#  4 5 7
#  2 6 1
#
#  8 0 3
#  4 5 7
#  2 6 1
#
#  8 5 3
#  4 0 7
#  2 6 1
#
#  0 8 3
#  4 5 7
#  2 6 1
#
#  4 8 7
#  2 3 5
#  0 6 1
#
#  4 8 7
#  2 3 5
#  6 0 1
#
#  4 8 7
#  2 0 5
#  6 3 1
#
#  4 8 7
#  0 2 5
#  6 3 1
#
#  0 8 7
#  4 2 5
#  6 3 1
#
#  8 0 7
#  4 2 5
#  6 3 1
#
#  8 2 7
#  4 0 5
#  6 3 1
#
#  8 7 0
#  4 2 5
#  6 3 1
#
#  4 0 7
#  2 8 5
#  6 3 1
#
#  0 4 7
#  2 8 5
#  6 3 1
#
#  2 4 7
#  0 8 5
#  6 3 1
#
#  2 4 7
#  8 0 5
#  6 3 1
#
#  2 4 7
#  6 8 5
#  0 3 1
#
#  4 8 7
#  6 2 5
#  0 3 1
#
#  4 8 7
#  6 2 5
#  3 0 1
#
#  4 8 7
#  6 0 5
#  3 2 1
#
#  4 7 0
#  2 8 5
#  6 3 1
#
#  4 7 5
#  2 8 0
#  6 3 1
#
#  4 7 5
#  2 0 8
#  6 3 1
#
#  4 8 7
#  6 2 5
#  3 1 0
#
#  4 7 5
#  2 8 1
#  6 3 0
#
#  4 8 7
#  2 5 0
#  6 3 1
#
#  4 8 0
#  2 5 7
#  6 3 1
#
#  4 0 8
#  2 5 7
#  6 3 1
#
#  0 4 8
#  2 5 7
#  6 3 1
#
#  4 5 8
#  2 0 7
#  6 3 1
#
#  4 8 7
#  2 5 1
#  6 3 0
#
#  4 8 7
#  2 5 1
#  6 0 3
#
#  4 8 7
#  2 0 1
#  6 5 3
#
#  4 8 7
#  2 5 1
#  0 6 3
#
#  8 3 7
#  4 6 5
#  2 1 0
#
#  8 3 7
#  4 6 0
#  2 1 5
#
#  8 3 7
#  4 0 6
#  2 1 5
#
#  8 3 0
#  4 6 7
#  2 1 5
#
#  8 3 7
#  4 5 1
#  2 6 0
#
#  8 3 7
#  4 5 1
#  2 0 6
#
#  8 3 7
#  4 0 1
#  2 5 6
#
#  8 3 7
#  4 5 1
#  0 2 6
#
#  4 8 7
#  2 3 5
#  6 1 0
#
#  4 8 7
#  2 3 0
#  6 1 5
#
#  4 8 7
#  2 0 3
#  6 1 5
#
#  4 8 7
#  0 2 3
#  6 1 5
#
#  0 8 7
#  4 2 3
#  6 1 5
#
#  4 0 7
#  2 8 3
#  6 1 5
#
#  0 4 7
#  2 8 3
#  6 1 5
#
#  4 8 0
#  2 3 7
#  6 1 5
#
#  4 0 8
#  2 3 7
#  6 1 5
#
#  0 4 8
#  2 3 7
#  6 1 5
#
#  4 3 8
#  2 0 7
#  6 1 5
#
#  4 8 7
#  6 2 3
#  0 1 5
#
#  4 7 0
#  2 8 3
#  6 1 5
#
#  4 8 7
#  2 1 3
#  6 0 5
#
#  4 8 7
#  2 1 3
#  0 6 5
#
#  4 8 7
#  2 1 3
#  6 5 0
#
#  4 8 7
#  3 6 5
#  2 0 1
#
#  4 8 7
#  3 6 5
#  0 2 1
#
#  4 8 7
#  0 6 5
#  3 2 1
#
#  0 8 7
#  4 6 5
#  3 2 1
#
#  8 0 7
#  4 6 5
#  3 2 1
#
#  8 6 7
#  4 0 5
#  3 2 1
#
#  8 6 7
#  0 4 5
#  3 2 1
#
#  0 6 7
#  8 4 5
#  3 2 1
#
#  8 6 7
#  3 4 5
#  0 2 1
#
#  8 6 7
#  4 2 5
#  3 0 1
#
#  8 6 7
#  4 2 5
#  0 3 1
#
#  8 6 7
#  4 5 0
#  3 2 1
#
#  8 6 0
#  4 5 7
#  3 2 1
#
#  8 7 0
#  4 6 5
#  3 2 1
#
#  8 7 5
#  4 6 0
#  3 2 1
#
#  8 7 5
#  4 0 6
#  3 2 1
#
#  8 6 7
#  4 2 5
#  3 1 0
#
#  8 6 7
#  4 5 1
#  3 2 0
#
#  8 7 5
#  4 6 1
#  3 2 0
#
#  4 8 7
#  3 5 0
#  2 6 1
#
#  4 8 0
#  3 5 7
#  2 6 1
#
#  4 0 8
#  3 5 7
#  2 6 1
#
#  0 4 8
#  3 5 7
#  2 6 1
#
#  3 4 8
#  0 5 7
#  2 6 1
#
#  3 4 8
#  5 0 7
#  2 6 1
#
#  3 0 8
#  5 4 7
#  2 6 1
#
#  0 3 8
#  5 4 7
#  2 6 1
#
#  3 8 0
#  5 4 7
#  2 6 1
#
#  3 4 8
#  5 6 7
#  2 0 1
#
#  3 4 8
#  5 6 7
#  0 2 1
#
#  3 4 8
#  5 7 0
#  2 6 1
#
#  3 4 0
#  5 7 8
#  2 6 1
#
#  4 5 8
#  3 0 7
#  2 6 1
#
#  4 5 8
#  0 3 7
#  2 6 1
#
#  0 5 8
#  4 3 7
#  2 6 1
#
#  5 0 8
#  4 3 7
#  2 6 1
#
#  5 3 8
#  4 0 7
#  2 6 1
#
#  5 8 0
#  4 3 7
#  2 6 1
#
#  3 4 8
#  2 5 7
#  0 6 1
#
#  3 4 8
#  2 5 7
#  6 0 1
#
#  3 4 8
#  2 0 7
#  6 5 1
#
#  3 4 8
#  5 6 7
#  2 1 0
#
#  3 4 8
#  5 7 1
#  2 6 0
#
#  4 5 8
#  2 3 7
#  0 6 1
#
#  4 5 8
#  2 3 7
#  6 0 1
#
#  3 4 8
#  2 5 7
#  6 1 0
#
#  4 5 8
#  2 3 7
#  6 1 0
#
#  4 5 8
#  3 6 7
#  2 0 1
#
#  4 5 8
#  3 6 7
#  0 2 1
#
#  4 5 8
#  0 6 7
#  3 2 1
#
#  4 5 8
#  6 0 7
#  3 2 1
#
#  0 5 8
#  4 6 7
#  3 2 1
#
#  4 5 8
#  3 7 0
#  2 6 1
#
#  4 5 0
#  3 7 8
#  2 6 1
#
#  4 0 5
#  3 7 8
#  2 6 1
#
#  0 4 5
#  3 7 8
#  2 6 1
#
#  4 7 5
#  3 0 8
#  2 6 1
#
#  4 5 8
#  3 6 7
#  2 1 0
#
#  4 5 8
#  3 6 0
#  2 1 7
#
#  4 5 8
#  3 0 6
#  2 1 7
#
#  4 5 0
#  3 6 8
#  2 1 7
#
#  4 5 8
#  3 7 1
#  2 6 0
#
#  4 5 8
#  3 7 1
#  2 0 6
#
#  4 5 8
#  3 7 1
#  0 2 6
#
#  4 5 8
#  3 0 1
#  2 7 6
#
#  4 7 0
#  3 8 5
#  2 6 1
#
#  4 7 5
#  3 8 0
#  2 6 1
#
#  4 8 7
#  3 6 5
#  2 1 0
#
#  4 8 7
#  3 6 0
#  2 1 5
#
#  4 8 7
#  3 0 6
#  2 1 5
#
#  4 8 7
#  0 3 6
#  2 1 5
#
#  0 8 7
#  4 3 6
#  2 1 5
#
#  8 0 7
#  4 3 6
#  2 1 5
#
#  8 7 0
#  4 3 6
#  2 1 5
#
#  4 0 7
#  3 8 6
#  2 1 5
#
#  0 4 7
#  3 8 6
#  2 1 5
#
#  3 4 7
#  0 8 6
#  2 1 5
#
#  3 4 7
#  8 0 6
#  2 1 5
#
#  3 4 7
#  2 8 6
#  0 1 5
#
#  4 8 0
#  3 6 7
#  2 1 5
#
#  4 0 8
#  3 6 7
#  2 1 5
#
#  0 4 8
#  3 6 7
#  2 1 5
#
#  3 4 8
#  0 6 7
#  2 1 5
#
#  3 4 8
#  6 0 7
#  2 1 5
#
#  4 6 8
#  3 0 7
#  2 1 5
#
#  4 6 8
#  0 3 7
#  2 1 5
#
#  0 6 8
#  4 3 7
#  2 1 5
#
#  3 4 8
#  2 6 7
#  0 1 5
#
#  4 6 8
#  2 3 7
#  0 1 5
#
#  4 6 8
#  3 1 7
#  2 0 5
#
#  4 6 8
#  3 1 7
#  0 2 5
#
#  4 6 8
#  3 7 0
#  2 1 5
#
#  4 6 0
#  3 7 8
#  2 1 5
#
#  4 6 8
#  3 1 7
#  2 5 0
#
#  4 6 8
#  3 7 5
#  2 1 0
#
#  4 8 7
#  2 3 6
#  0 1 5
#
#  4 7 0
#  3 8 6
#  2 1 5
#
#  4 7 6
#  3 8 0
#  2 1 5
#
#  4 7 6
#  3 0 8
#  2 1 5
#
#  4 7 6
#  3 8 5
#  2 1 0
#
#  4 8 7
#  3 1 6
#  2 0 5
#
#  4 8 7
#  3 1 6
#  0 2 5
#
#  4 8 7
#  0 1 6
#  3 2 5
#
#  0 8 7
#  4 1 6
#  3 2 5
#
#  4 8 7
#  1 0 6
#  3 2 5
#
#  4 8 7
#  2 3 6
#  1 0 5
#
#  4 8 7
#  2 0 6
#  1 3 5
#
#  4 8 7
#  3 1 6
#  2 5 0
#
#  4 8 7
#  3 1 0
#  2 5 6
#
#  4 8 7
#  3 0 1
#  2 5 6
#
#  4 8 0
#  3 1 7
#  2 5 6
#
#  4 8 7
#  2 3 6
#  1 5 0
#
#  4 8 7
#  3 5 1
#  2 6 0
#
#  4 8 7
#  3 5 1
#  2 0 6
#
#  4 8 7
#  3 5 1
#  0 2 6
#
#  4 8 7
#  0 5 1
#  3 2 6
#
#  4 8 7
#  5 0 1
#  3 2 6
#
#  4 0 7
#  5 8 1
#  3 2 6
#
#  0 4 7
#  5 8 1
#  3 2 6
#
#  0 8 7
#  4 5 1
#  3 2 6
#
#  8 0 7
#  4 5 1
#  3 2 6
#
#  8 5 7
#  4 0 1
#  3 2 6
#
#  4 7 0
#  5 8 1
#  3 2 6
#
#  8 7 0
#  4 5 1
#  3 2 6
#
#  4 8 7
#  5 2 1
#  3 0 6
#
#  4 8 7
#  5 2 1
#  3 6 0
#
#  4 8 7
#  5 2 1
#  0 3 6
#
#  4 8 7
#  5 1 0
#  3 2 6
#
#  4 8 0
#  5 1 7
#  3 2 6
#
#  4 8 7
#  5 1 6
#  3 2 0
#
#  4 7 5
#  3 8 1
#  2 6 0
#
#  4 7 5
#  3 8 1
#  2 0 6
#
#  4 7 5
#  3 8 1
#  0 2 6
#
#  4 7 5
#  0 8 1
#  3 2 6
#
#  4 7 5
#  8 0 1
#  3 2 6
#
#  4 0 5
#  8 7 1
#  3 2 6
#
#  0 4 5
#  8 7 1
#  3 2 6
#
#  0 7 5
#  4 8 1
#  3 2 6
#
#  4 5 0
#  8 7 1
#  3 2 6
#
#  4 7 5
#  8 2 1
#  3 0 6
#
#  4 7 5
#  8 2 1
#  3 6 0
#
#  4 7 5
#  8 2 1
#  0 3 6
#
#  4 7 5
#  8 1 0
#  3 2 6
#
#  4 7 0
#  8 1 5
#  3 2 6
#
#  7 0 5
#  4 8 1
#  3 2 6
#
#  7 8 5
#  4 0 1
#  3 2 6
#
#  4 7 5
#  8 1 6
#  3 2 0
#
#  7 5 0
#  4 8 1
#  3 2 6
#
#  4 7 5
#  3 0 1
#  2 8 6
#
#  4 7 5
#  0 3 1
#  2 8 6
#
#  0 7 5
#  4 3 1
#  2 8 6
#
#  4 0 5
#  3 7 1
#  2 8 6
#
#  0 4 5
#  3 7 1
#  2 8 6
#
#  3 4 5
#  0 7 1
#  2 8 6
#
#  3 4 5
#  2 7 1
#  0 8 6
#
#  3 4 5
#  7 0 1
#  2 8 6
#
#  7 0 5
#  4 3 1
#  2 8 6
#
#  4 7 5
#  2 3 1
#  0 8 6
#
#  4 7 5
#  2 3 1
#  8 0 6
#
#  4 7 5
#  2 0 1
#  8 3 6
#
#  4 7 5
#  2 3 1
#  8 6 0
#
#  4 5 0
#  3 7 1
#  2 8 6
#
#  7 3 5
#  4 0 1
#  2 8 6
#
#  7 5 0
#  4 3 1
#  2 8 6
#
#  4 7 5
#  3 1 0
#  2 8 6
#
#  4 7 0
#  3 1 5
#  2 8 6
#
#  4 0 7
#  3 1 5
#  2 8 6
#
#  0 4 7
#  3 1 5
#  2 8 6
#
#  4 1 7
#  3 0 5
#  2 8 6
#
#  4 5 1
#  3 7 0
#  2 8 6
#
#  4 5 1
#  3 0 7
#  2 8 6
#
#  4 7 5
#  3 1 6
#  2 8 0
#
#  4 7 5
#  3 1 6
#  2 0 8
#
#  4 7 5
#  3 0 6
#  2 1 8
#
#  4 7 5
#  3 1 6
#  0 2 8
#
#  4 5 1
#  3 7 6
#  2 8 0
#
#  3 0 7
#  8 4 5
#  2 6 1
#
#  3 4 7
#  2 8 5
#  0 6 1
#
#  3 4 7
#  2 8 5
#  6 0 1
#
#  3 4 7
#  2 0 5
#  6 8 1
#
#  3 4 7
#  0 2 5
#  6 8 1
#
#  0 4 7
#  3 2 5
#  6 8 1
#
#  4 0 7
#  3 2 5
#  6 8 1
#
#  4 2 7
#  3 0 5
#  6 8 1
#
#  4 2 7
#  3 8 5
#  6 0 1
#
#  4 2 7
#  3 8 5
#  0 6 1
#
#  4 2 7
#  0 8 5
#  3 6 1
#
#  4 2 7
#  8 0 5
#  3 6 1
#
#  0 2 7
#  4 8 5
#  3 6 1
#
#  4 2 7
#  0 3 5
#  6 8 1
#
#  0 2 7
#  4 3 5
#  6 8 1
#
#  2 0 7
#  4 3 5
#  6 8 1
#
#  2 3 7
#  4 0 5
#  6 8 1
#
#  2 7 0
#  4 3 5
#  6 8 1
#
#  4 7 0
#  3 2 5
#  6 8 1
#
#  4 7 5
#  3 2 0
#  6 8 1
#
#  4 7 5
#  3 0 2
#  6 8 1
#
#  4 7 5
#  3 8 2
#  6 0 1
#
#  4 7 5
#  3 8 2
#  0 6 1
#
#  4 7 5
#  0 3 2
#  6 8 1
#
#  0 7 5
#  4 3 2
#  6 8 1
#
#  4 0 5
#  3 7 2
#  6 8 1
#
#  0 4 5
#  3 7 2
#  6 8 1
#
#  4 7 5
#  3 8 2
#  6 1 0
#
#  4 7 5
#  6 3 2
#  0 8 1
#
#  4 5 0
#  3 7 2
#  6 8 1
#
#  4 2 7
#  3 8 5
#  6 1 0
#
#  4 2 7
#  3 8 0
#  6 1 5
#
#  4 2 7
#  3 0 8
#  6 1 5
#
#  4 2 0
#  3 8 7
#  6 1 5
#
#  4 2 7
#  6 3 5
#  0 8 1
#
#  4 2 7
#  6 3 5
#  8 0 1
#
#  4 2 7
#  6 0 5
#  8 3 1
#
#  4 7 5
#  3 2 1
#  6 8 0
#
#  4 7 5
#  3 2 1
#  6 0 8
#
#  4 7 5
#  3 0 1
#  6 2 8
#
#  4 7 5
#  3 2 1
#  0 6 8
#
#  4 2 7
#  6 3 5
#  8 1 0
#
#  3 0 7
#  2 4 5
#  6 8 1
#
#  0 3 7
#  2 4 5
#  6 8 1
#
#  4 2 7
#  3 5 0
#  6 8 1
#
#  4 2 0
#  3 5 7
#  6 8 1
#
#  4 0 2
#  3 5 7
#  6 8 1
#
#  0 4 2
#  3 5 7
#  6 8 1
#
#  4 5 2
#  3 0 7
#  6 8 1
#
#  2 3 7
#  0 4 5
#  6 8 1
#
#  3 4 7
#  6 2 5
#  0 8 1
#
#  3 4 7
#  6 2 5
#  8 0 1
#
#  3 4 7
#  6 0 5
#  8 2 1
#
#  3 4 7
#  0 6 5
#  8 2 1
#
#  0 4 7
#  3 6 5
#  8 2 1
#
#  4 0 7
#  3 6 5
#  8 2 1
#
#  4 6 7
#  3 0 5
#  8 2 1
#
#  3 4 7
#  8 6 5
#  0 2 1
#
#  3 4 7
#  8 6 5
#  2 0 1
#
#  4 7 0
#  3 6 5
#  8 2 1
#
#  3 4 7
#  8 6 5
#  2 1 0
#
#  3 0 7
#  6 4 5
#  8 2 1
#
#  0 3 7
#  6 4 5
#  8 2 1
#
#  6 3 7
#  0 4 5
#  8 2 1
#
#  6 3 7
#  8 4 5
#  0 2 1
#
#  6 3 7
#  4 0 5
#  8 2 1
#
#  3 7 0
#  6 4 5
#  8 2 1
#
#  3 7 5
#  6 4 0
#  8 2 1
#
#  3 7 5
#  6 0 4
#  8 2 1
#
#  3 7 5
#  6 4 1
#  8 2 0
#
#  3 4 7
#  6 5 0
#  8 2 1
#
#  3 4 0
#  6 5 7
#  8 2 1
#
#  3 0 4
#  6 5 7
#  8 2 1
#
#  3 5 4
#  6 0 7
#  8 2 1
#
#  0 3 4
#  6 5 7
#  8 2 1
#
#  3 4 7
#  6 5 1
#  8 2 0
#
#  3 4 7
#  6 5 1
#  8 0 2
#
#  3 4 7
#  6 0 1
#  8 5 2
#
#  3 4 7
#  6 5 1
#  0 8 2
#
#  3 7 0
#  2 4 5
#  6 8 1
#
#  3 7 5
#  2 4 0
#  6 8 1
#
#  3 7 5
#  2 0 4
#  6 8 1
#
#  3 7 5
#  2 8 4
#  6 0 1
#
#  3 7 5
#  2 8 4
#  0 6 1
#
#  3 7 5
#  0 8 4
#  2 6 1
#
#  0 7 5
#  3 8 4
#  2 6 1
#
#  3 7 5
#  8 0 4
#  2 6 1
#
#  3 7 5
#  0 2 4
#  6 8 1
#
#  0 7 5
#  3 2 4
#  6 8 1
#
#  7 0 5
#  3 2 4
#  6 8 1
#
#  7 2 5
#  3 0 4
#  6 8 1
#
#  7 5 0
#  3 2 4
#  6 8 1
#
#  3 0 5
#  2 7 4
#  6 8 1
#
#  0 3 5
#  2 7 4
#  6 8 1
#
#  2 3 5
#  0 7 4
#  6 8 1
#
#  3 7 5
#  2 8 4
#  6 1 0
#
#  3 7 5
#  2 8 0
#  6 1 4
#
#  3 7 5
#  2 0 8
#  6 1 4
#
#  3 7 0
#  2 8 5
#  6 1 4
#
#  3 7 5
#  6 2 4
#  0 8 1
#
#  3 7 5
#  6 2 4
#  8 0 1
#
#  3 5 0
#  2 7 4
#  6 8 1
#
#  3 5 4
#  2 7 0
#  6 8 1
#
#  3 5 4
#  2 0 7
#  6 8 1
#
#  2 3 5
#  6 7 4
#  0 8 1
#
#  2 3 5
#  7 0 4
#  6 8 1
#
#  3 7 5
#  6 2 4
#  8 1 0
#
#  3 5 4
#  2 7 1
#  6 8 0
#
#  4 2 7
#  3 5 1
#  6 8 0
#
#  4 2 7
#  3 5 1
#  6 0 8
#
#  4 2 7
#  3 0 1
#  6 5 8
#
#  4 2 7
#  3 5 1
#  0 6 8
#
#  2 3 7
#  6 4 5
#  0 8 1
#
#  2 3 7
#  6 4 5
#  8 0 1
#
#  2 3 7
#  6 0 5
#  8 4 1
#
#  2 0 7
#  6 3 5
#  8 4 1
#
#  0 2 7
#  6 3 5
#  8 4 1
#
#  2 7 0
#  6 3 5
#  8 4 1
#
#  2 3 7
#  0 6 5
#  8 4 1
#
#  0 3 7
#  2 6 5
#  8 4 1
#
#  2 3 7
#  8 6 5
#  0 4 1
#
#  2 3 7
#  6 5 0
#  8 4 1
#
#  2 3 0
#  6 5 7
#  8 4 1
#
#  2 3 7
#  6 5 1
#  8 4 0
#
#  3 4 7
#  6 2 5
#  8 1 0
#
#  3 4 7
#  6 2 0
#  8 1 5
#
#  3 4 7
#  6 0 2
#  8 1 5
#
#  3 4 7
#  0 6 2
#  8 1 5
#
#  0 4 7
#  3 6 2
#  8 1 5
#
#  3 4 7
#  8 6 2
#  0 1 5
#
#  3 0 7
#  6 4 2
#  8 1 5
#
#  0 3 7
#  6 4 2
#  8 1 5
#
#  3 7 0
#  6 4 2
#  8 1 5
#
#  3 4 7
#  6 1 2
#  8 0 5
#
#  3 4 7
#  6 1 2
#  0 8 5
#
#  3 4 0
#  6 2 7
#  8 1 5
#
#  3 0 4
#  6 2 7
#  8 1 5
#
#  0 3 4
#  6 2 7
#  8 1 5
#
#  3 2 4
#  6 0 7
#  8 1 5
#
#  3 4 7
#  6 1 2
#  8 5 0
#
#  3 7 5
#  2 4 1
#  6 8 0
#
#  3 7 5
#  2 4 1
#  6 0 8
#
#  3 7 5
#  2 0 1
#  6 4 8
#
#  3 7 5
#  0 2 1
#  6 4 8
#
#  0 7 5
#  3 2 1
#  6 4 8
#
#  3 0 5
#  2 7 1
#  6 4 8
#
#  0 3 5
#  2 7 1
#  6 4 8
#
#  3 7 5
#  6 2 1
#  0 4 8
#
#  3 5 0
#  2 7 1
#  6 4 8
#
#  3 7 5
#  2 1 0
#  6 4 8
#
#  3 7 5
#  2 1 8
#  6 4 0
#
#  3 7 0
#  2 1 5
#  6 4 8
#
#  3 7 5
#  2 4 1
#  0 6 8
#
#  3 7 5
#  0 4 1
#  2 6 8
#
#  0 7 5
#  3 4 1
#  2 6 8
#
#  3 7 5
#  4 0 1
#  2 6 8
#
#  2 3 7
#  6 4 5
#  8 1 0
#
#  2 3 7
#  6 4 0
#  8 1 5
#
#  2 3 7
#  6 0 4
#  8 1 5
#
#  2 3 0
#  6 4 7
#  8 1 5
#
#  3 4 7
#  2 5 0
#  6 8 1
#
#  3 4 0
#  2 5 7
#  6 8 1
#
#  3 0 4
#  2 5 7
#  6 8 1
#
#  0 3 4
#  2 5 7
#  6 8 1
#
#  2 3 4
#  0 5 7
#  6 8 1
#
#  2 3 4
#  5 0 7
#  6 8 1
#
#  2 0 4
#  5 3 7
#  6 8 1
#
#  0 2 4
#  5 3 7
#  6 8 1
#
#  2 4 0
#  5 3 7
#  6 8 1
#
#  2 3 4
#  5 8 7
#  6 0 1
#
#  2 3 4
#  5 8 7
#  0 6 1
#
#  2 3 4
#  5 8 7
#  6 1 0
#
#  2 3 4
#  5 7 0
#  6 8 1
#
#  2 3 0
#  5 7 4
#  6 8 1
#
#  2 3 4
#  6 5 7
#  0 8 1
#
#  2 3 4
#  6 5 7
#  8 0 1
#
#  2 3 4
#  6 0 7
#  8 5 1
#
#  2 3 4
#  5 7 1
#  6 8 0
#
#  2 3 4
#  6 5 7
#  8 1 0
#
#  3 4 7
#  2 8 5
#  6 1 0
#
#  3 4 7
#  2 8 0
#  6 1 5
#
#  3 4 7
#  2 0 8
#  6 1 5
#
#  3 4 7
#  0 2 8
#  6 1 5
#
#  0 4 7
#  3 2 8
#  6 1 5
#
#  4 0 7
#  3 2 8
#  6 1 5
#
#  4 7 0
#  3 2 8
#  6 1 5
#
#  4 7 8
#  3 2 0
#  6 1 5
#
#  4 7 8
#  3 0 2
#  6 1 5
#
#  4 7 8
#  3 2 5
#  6 1 0
#
#  3 0 7
#  2 4 8
#  6 1 5
#
#  0 3 7
#  2 4 8
#  6 1 5
#
#  2 3 7
#  0 4 8
#  6 1 5
#
#  3 4 7
#  6 2 8
#  0 1 5
#
#  3 7 0
#  2 4 8
#  6 1 5
#
#  3 7 8
#  2 4 0
#  6 1 5
#
#  3 7 8
#  2 0 4
#  6 1 5
#
#  3 7 8
#  0 2 4
#  6 1 5
#
#  0 7 8
#  3 2 4
#  6 1 5
#
#  3 0 8
#  2 7 4
#  6 1 5
#
#  0 3 8
#  2 7 4
#  6 1 5
#
#  3 7 8
#  6 2 4
#  0 1 5
#
#  3 8 0
#  2 7 4
#  6 1 5
#
#  3 7 8
#  2 1 4
#  6 0 5
#
#  3 7 8
#  2 1 4
#  0 6 5
#
#  3 7 8
#  2 1 4
#  6 5 0
#
#  2 3 7
#  6 4 8
#  0 1 5
#
#  2 3 7
#  4 0 8
#  6 1 5
#
#  2 0 7
#  4 3 8
#  6 1 5
#
#  0 2 7
#  4 3 8
#  6 1 5
#
#  2 7 0
#  4 3 8
#  6 1 5
#
#  3 7 8
#  2 4 5
#  6 1 0
#
#  3 7 8
#  2 4 5
#  6 0 1
#
#  3 7 8
#  2 0 5
#  6 4 1
#
#  3 7 8
#  2 4 5
#  0 6 1
#
#  3 4 7
#  2 1 8
#  6 0 5
#
#  3 4 7
#  2 1 8
#  0 6 5
#
#  3 4 7
#  0 1 8
#  2 6 5
#
#  0 4 7
#  3 1 8
#  2 6 5
#
#  4 0 7
#  3 1 8
#  2 6 5
#
#  4 1 7
#  3 0 8
#  2 6 5
#
#  4 7 0
#  3 1 8
#  2 6 5
#
#  3 4 7
#  1 0 8
#  2 6 5
#
#  3 0 7
#  1 4 8
#  2 6 5
#
#  0 3 7
#  1 4 8
#  2 6 5
#
#  3 7 0
#  1 4 8
#  2 6 5
#
#  3 4 7
#  1 6 8
#  2 0 5
#
#  3 4 7
#  1 6 8
#  0 2 5
#
#  3 4 7
#  1 8 0
#  2 6 5
#
#  3 4 0
#  1 8 7
#  2 6 5
#
#  3 4 7
#  1 6 8
#  2 5 0
#
#  3 4 7
#  1 8 5
#  2 6 0
#
#  3 4 7
#  6 2 8
#  1 0 5
#
#  3 4 7
#  6 0 8
#  1 2 5
#
#  3 4 7
#  0 6 8
#  1 2 5
#
#  0 4 7
#  3 6 8
#  1 2 5
#
#  3 0 7
#  6 4 8
#  1 2 5
#
#  0 3 7
#  6 4 8
#  1 2 5
#
#  3 7 0
#  6 4 8
#  1 2 5
#
#  3 4 7
#  6 8 0
#  1 2 5
#
#  3 4 0
#  6 8 7
#  1 2 5
#
#  3 4 7
#  6 8 5
#  1 2 0
#
#  2 3 7
#  6 4 8
#  1 0 5
#
#  2 3 7
#  6 0 8
#  1 4 5
#
#  2 3 7
#  4 1 8
#  6 0 5
#
#  2 3 7
#  4 1 8
#  0 6 5
#
#  2 3 7
#  4 8 0
#  6 1 5
#
#  2 3 0
#  4 8 7
#  6 1 5
#
#  3 4 0
#  2 8 7
#  6 1 5
#
#  3 0 4
#  2 8 7
#  6 1 5
#
#  3 8 4
#  2 0 7
#  6 1 5
#
#  3 8 4
#  0 2 7
#  6 1 5
#
#  0 8 4
#  3 2 7
#  6 1 5
#
#  8 0 4
#  3 2 7
#  6 1 5
#
#  8 2 4
#  3 0 7
#  6 1 5
#
#  8 4 0
#  3 2 7
#  6 1 5
#
#  0 3 4
#  2 8 7
#  6 1 5
#
#  3 8 4
#  6 2 7
#  0 1 5
#
#  3 8 4
#  2 1 7
#  6 0 5
#
#  3 8 4
#  2 1 7
#  0 6 5
#
#  3 8 4
#  0 1 7
#  2 6 5
#
#  0 8 4
#  3 1 7
#  2 6 5
#
#  3 8 4
#  1 0 7
#  2 6 5
#
#  3 8 4
#  2 7 0
#  6 1 5
#
#  2 3 4
#  0 8 7
#  6 1 5
#
#  2 3 4
#  8 0 7
#  6 1 5
#
#  2 0 4
#  8 3 7
#  6 1 5
#
#  0 2 4
#  8 3 7
#  6 1 5
#
#  2 4 0
#  8 3 7
#  6 1 5
#
#  3 8 4
#  6 2 7
#  1 0 5
#
#  3 8 4
#  6 0 7
#  1 2 5
#
#  2 3 4
#  8 1 7
#  6 0 5
#
#  2 3 4
#  8 1 7
#  0 6 5
#
#  2 3 4
#  8 7 0
#  6 1 5
#
#  2 3 0
#  8 7 4
#  6 1 5
#
#  3 8 4
#  2 1 7
#  6 5 0
#
#  3 8 4
#  2 1 0
#  6 5 7
#
#  3 8 4
#  2 0 1
#  6 5 7
#
#  3 8 0
#  2 1 4
#  6 5 7
#
#  3 8 4
#  2 7 5
#  6 1 0
#
#  3 8 4
#  2 7 5
#  6 0 1
#
#  3 8 4
#  2 7 5
#  0 6 1
#
#  3 8 4
#  2 0 5
#  6 7 1
#
#  2 3 4
#  6 8 7
#  0 1 5
#
#  3 8 4
#  6 2 7
#  1 5 0
#
#  2 3 4
#  8 1 7
#  6 5 0
#
#  2 3 4
#  8 7 5
#  6 1 0
#
#  2 3 4
#  6 8 7
#  1 0 5
#
#  2 3 4
#  6 0 7
#  1 8 5
#
#  3 4 7
#  2 1 8
#  6 5 0
#
#  3 4 7
#  2 1 0
#  6 5 8
#
#  3 4 7
#  2 0 1
#  6 5 8
#
#  3 4 7
#  0 2 1
#  6 5 8
#
#  0 4 7
#  3 2 1
#  6 5 8
#
#  3 0 7
#  2 4 1
#  6 5 8
#
#  0 3 7
#  2 4 1
#  6 5 8
#
#  3 4 7
#  6 2 1
#  0 5 8
#
#  3 7 0
#  2 4 1
#  6 5 8
#
#  3 4 7
#  2 5 1
#  6 0 8
#
#  3 4 7
#  2 5 1
#  0 6 8
#
#  3 4 0
#  2 1 7
#  6 5 8
#
#  3 0 4
#  2 1 7
#  6 5 8
#
#  0 3 4
#  2 1 7
#  6 5 8
#
#  3 1 4
#  2 0 7
#  6 5 8
#
#  3 4 7
#  2 5 1
#  6 8 0
#
#  3 4 7
#  6 2 8
#  1 5 0
#
#  3 4 7
#  6 2 0
#  1 5 8
#
#  3 4 7
#  6 0 2
#  1 5 8
#
#  3 4 0
#  6 2 7
#  1 5 8
#
#  2 3 7
#  6 4 8
#  1 5 0
#
#  2 3 7
#  4 1 8
#  6 5 0
#
#  2 3 7
#  4 8 5
#  6 1 0
#
#  2 3 4
#  6 8 7
#  1 5 0
#
#  3 4 7
#  2 5 1
#  6 8 0
#
#  3 4 7
#  8 6 5
#  2 0 1
#
#  3 4 7
#  8 5 1
#  2 6 0
#
#  3 4 7
#  8 5 1
#  2 0 6
#
#  3 4 7
#  8 0 1
#  2 5 6
#
#  3 4 7
#  0 8 1
#  2 5 6
#
#  0 4 7
#  3 8 1
#  2 5 6
#
#  4 0 7
#  3 8 1
#  2 5 6
#
#  4 7 0
#  3 8 1
#  2 5 6
#
#  3 0 7
#  8 4 1
#  2 5 6
#
#  0 3 7
#  8 4 1
#  2 5 6
#
#  8 3 7
#  0 4 1
#  2 5 6
#
#  8 3 7
#  2 4 1
#  0 5 6
#
#  8 3 7
#  2 4 1
#  5 0 6
#
#  8 3 7
#  2 0 1
#  5 4 6
#
#  8 0 7
#  2 3 1
#  5 4 6
#
#  0 8 7
#  2 3 1
#  5 4 6
#
#  2 8 7
#  0 3 1
#  5 4 6
#
#  2 8 7
#  3 0 1
#  5 4 6
#
#  8 7 0
#  2 3 1
#  5 4 6
#
#  2 8 7
#  5 3 1
#  0 4 6
#
#  8 3 7
#  0 2 1
#  5 4 6
#
#  0 3 7
#  8 2 1
#  5 4 6
#
#  3 0 7
#  8 2 1
#  5 4 6
#
#  3 2 7
#  8 0 1
#  5 4 6
#
#  3 7 0
#  8 2 1
#  5 4 6
#
#  8 7 1
#  2 3 0
#  5 4 6
#
#  8 7 1
#  2 0 3
#  5 4 6
#
#  8 3 7
#  5 2 1
#  0 4 6
#
#  8 7 1
#  2 3 6
#  5 4 0
#
#  8 3 7
#  2 1 0
#  5 4 6
#
#  8 3 0
#  2 1 7
#  5 4 6
#
#  8 0 3
#  2 1 7
#  5 4 6
#
#  0 8 3
#  2 1 7
#  5 4 6
#
#  8 1 3
#  2 0 7
#  5 4 6
#
#  8 3 7
#  5 2 1
#  4 0 6
#
#  8 3 7
#  5 0 1
#  4 2 6
#
#  8 3 7
#  5 2 1
#  4 6 0
#
#  8 3 7
#  2 4 1
#  5 6 0
#
#  8 3 7
#  2 4 0
#  5 6 1
#
#  8 3 7
#  2 0 4
#  5 6 1
#
#  8 0 7
#  2 3 4
#  5 6 1
#
#  0 8 7
#  2 3 4
#  5 6 1
#
#  8 7 0
#  2 3 4
#  5 6 1
#
#  8 3 7
#  0 2 4
#  5 6 1
#
#  0 3 7
#  8 2 4
#  5 6 1
#
#  8 3 7
#  5 2 4
#  0 6 1
#
#  8 3 7
#  2 6 4
#  5 0 1
#
#  8 3 7
#  2 6 4
#  0 5 1
#
#  8 3 0
#  2 4 7
#  5 6 1
#
#  8 0 3
#  2 4 7
#  5 6 1
#
#  8 4 3
#  2 0 7
#  5 6 1
#
#  0 8 3
#  2 4 7
#  5 6 1
#
#  8 3 7
#  2 6 4
#  5 1 0
#
#  8 3 7
#  2 1 6
#  5 4 0
#
#  8 3 7
#  2 1 6
#  5 0 4
#
#  8 3 7
#  2 0 6
#  5 1 4
#
#  8 3 7
#  2 1 6
#  0 5 4
#
#  4 7 1
#  3 8 0
#  2 5 6
#
#  4 7 1
#  3 0 8
#  2 5 6
#
#  4 7 1
#  0 3 8
#  2 5 6
#
#  0 7 1
#  4 3 8
#  2 5 6
#
#  4 0 1
#  3 7 8
#  2 5 6
#
#  0 4 1
#  3 7 8
#  2 5 6
#
#  3 4 1
#  0 7 8
#  2 5 6
#
#  3 4 1
#  2 7 8
#  0 5 6
#
#  3 4 1
#  7 0 8
#  2 5 6
#
#  7 0 1
#  4 3 8
#  2 5 6
#
#  4 7 1
#  2 3 8
#  0 5 6
#
#  4 7 1
#  2 3 8
#  5 0 6
#
#  4 7 1
#  2 0 8
#  5 3 6
#
#  4 7 1
#  2 3 8
#  5 6 0
#
#  4 1 0
#  3 7 8
#  2 5 6
#
#  4 1 8
#  3 7 0
#  2 5 6
#
#  4 1 8
#  3 0 7
#  2 5 6
#
#  7 3 1
#  4 0 8
#  2 5 6
#
#  7 1 0
#  4 3 8
#  2 5 6
#
#  4 1 8
#  3 7 6
#  2 5 0
#
#  4 7 1
#  3 5 8
#  2 0 6
#
#  4 7 1
#  3 5 8
#  2 6 0
#
#  4 7 1
#  3 5 0
#  2 6 8
#
#  4 7 1
#  3 0 5
#  2 6 8
#
#  4 7 0
#  3 5 1
#  2 6 8
#
#  4 7 1
#  3 5 8
#  0 2 6
#
#  4 7 1
#  0 5 8
#  3 2 6
#
#  4 7 1
#  5 0 8
#  3 2 6
#
#  0 7 1
#  4 5 8
#  3 2 6
#
#  3 4 7
#  2 8 1
#  0 5 6
#
#  3 4 7
#  2 8 1
#  5 0 6
#
#  3 4 7
#  2 8 1
#  5 6 0
#
#  3 4 7
#  2 8 0
#  5 6 1
#
#  3 4 7
#  2 0 8
#  5 6 1
#
#  3 4 7
#  0 2 8
#  5 6 1
#
#  0 4 7
#  3 2 8
#  5 6 1
#
#  4 0 7
#  3 2 8
#  5 6 1
#
#  4 2 7
#  3 0 8
#  5 6 1
#
#  4 7 0
#  3 2 8
#  5 6 1
#
#  3 0 7
#  2 4 8
#  5 6 1
#
#  0 3 7
#  2 4 8
#  5 6 1
#
#  2 3 7
#  0 4 8
#  5 6 1
#
#  3 4 7
#  5 2 8
#  0 6 1
#
#  3 4 7
#  5 2 8
#  6 0 1
#
#  3 4 7
#  5 0 8
#  6 2 1
#
#  3 7 0
#  2 4 8
#  5 6 1
#
#  3 7 8
#  2 4 0
#  5 6 1
#
#  3 7 8
#  2 0 4
#  5 6 1
#
#  2 3 7
#  5 4 8
#  0 6 1
#
#  2 3 7
#  4 0 8
#  5 6 1
#
#  3 4 7
#  5 2 8
#  6 1 0
#
#  3 7 8
#  2 4 1
#  5 6 0
#
#  3 4 7
#  2 6 8
#  5 0 1
#
#  3 4 7
#  2 6 8
#  0 5 1
#
#  3 4 7
#  0 6 8
#  2 5 1
#
#  0 4 7
#  3 6 8
#  2 5 1
#
#  3 4 7
#  6 0 8
#  2 5 1
#
#  3 4 0
#  2 8 7
#  5 6 1
#
#  3 0 4
#  2 8 7
#  5 6 1
#
#  3 8 4
#  2 0 7
#  5 6 1
#
#  3 8 4
#  0 2 7
#  5 6 1
#
#  0 8 4
#  3 2 7
#  5 6 1
#
#  0 3 4
#  2 8 7
#  5 6 1
#
#  3 8 4
#  5 2 7
#  0 6 1
#
#  3 8 4
#  2 6 7
#  5 0 1
#
#  3 8 4
#  2 6 7
#  0 5 1
#
#  3 8 4
#  2 7 0
#  5 6 1
#
#  3 8 0
#  2 7 4
#  5 6 1
#
#  2 3 4
#  0 8 7
#  5 6 1
#
#  2 3 4
#  8 0 7
#  5 6 1
#
#  3 8 4
#  2 6 7
#  5 1 0
#
#  3 8 4
#  2 7 1
#  5 6 0
#
#  3 4 7
#  2 6 8
#  5 1 0
#
#  3 4 7
#  2 6 0
#  5 1 8
#
#  3 4 7
#  2 0 6
#  5 1 8
#
#  3 4 0
#  2 6 7
#  5 1 8
#
#  3 4 7
#  2 0 1
#  5 8 6
#
#  3 4 7
#  0 2 1
#  5 8 6
#
#  0 4 7
#  3 2 1
#  5 8 6
#
#  4 0 7
#  3 2 1
#  5 8 6
#
#  4 2 7
#  3 0 1
#  5 8 6
#
#  4 2 7
#  3 8 1
#  5 0 6
#
#  4 2 7
#  3 8 1
#  5 6 0
#
#  4 2 7
#  3 8 1
#  0 5 6
#
#  4 2 7
#  0 3 1
#  5 8 6
#
#  0 2 7
#  4 3 1
#  5 8 6
#
#  4 7 0
#  3 2 1
#  5 8 6
#
#  4 2 7
#  5 3 1
#  0 8 6
#
#  3 0 7
#  2 4 1
#  5 8 6
#
#  0 3 7
#  2 4 1
#  5 8 6
#
#  4 2 7
#  3 1 0
#  5 8 6
#
#  4 2 0
#  3 1 7
#  5 8 6
#
#  4 7 1
#  3 2 0
#  5 8 6
#
#  4 7 1
#  3 0 2
#  5 8 6
#
#  2 3 7
#  0 4 1
#  5 8 6
#
#  3 4 7
#  5 2 1
#  0 8 6
#
#  3 4 7
#  5 2 1
#  8 0 6
#
#  3 4 7
#  5 0 1
#  8 2 6
#
#  3 4 7
#  0 5 1
#  8 2 6
#
#  0 4 7
#  3 5 1
#  8 2 6
#
#  3 4 7
#  8 5 1
#  0 2 6
#
#  3 0 7
#  5 4 1
#  8 2 6
#
#  0 3 7
#  5 4 1
#  8 2 6
#
#  3 7 0
#  5 4 1
#  8 2 6
#
#  3 4 7
#  5 1 0
#  8 2 6
#
#  3 4 0
#  5 1 7
#  8 2 6
#
#  3 4 7
#  5 2 1
#  8 6 0
#
#  3 4 7
#  5 2 0
#  8 6 1
#
#  3 4 7
#  5 0 2
#  8 6 1
#
#  3 4 0
#  5 2 7
#  8 6 1
#
#  3 4 7
#  5 1 6
#  8 2 0
#
#  3 7 0
#  2 4 1
#  5 8 6
#
#  4 2 7
#  3 1 6
#  5 8 0
#
#  4 7 1
#  3 2 6
#  5 8 0
#
#  2 3 7
#  5 4 1
#  0 8 6
#
#  2 3 7
#  5 4 1
#  8 0 6
#
#  2 3 7
#  5 0 1
#  8 4 6
#
#  2 3 7
#  5 4 1
#  8 6 0
#
#  2 3 7
#  4 0 1
#  5 8 6
#
#  2 0 7
#  4 3 1
#  5 8 6
#
#  2 7 0
#  4 3 1
#  5 8 6
#
#  2 3 7
#  4 8 1
#  5 0 6
#
#  2 3 7
#  4 8 1
#  5 6 0
#
#  2 3 7
#  4 8 1
#  0 5 6
#
#  3 4 7
#  2 1 0
#  5 8 6
#
#  3 4 0
#  2 1 7
#  5 8 6
#
#  3 0 4
#  2 1 7
#  5 8 6
#
#  0 3 4
#  2 1 7
#  5 8 6
#
#  2 3 4
#  0 1 7
#  5 8 6
#
#  3 1 4
#  2 0 7
#  5 8 6
#
#  3 1 4
#  2 8 7
#  5 0 6
#
#  3 1 4
#  2 8 7
#  5 6 0
#
#  3 1 4
#  2 8 7
#  0 5 6
#
#  3 1 4
#  0 2 7
#  5 8 6
#
#  0 1 4
#  3 2 7
#  5 8 6
#
#  2 3 4
#  5 1 7
#  0 8 6
#
#  2 3 4
#  1 0 7
#  5 8 6
#
#  3 1 4
#  5 2 7
#  0 8 6
#
#  3 1 4
#  2 7 0
#  5 8 6
#
#  3 1 0
#  2 7 4
#  5 8 6
#
#  3 1 4
#  2 7 6
#  5 8 0
#
#  3 7 1
#  2 4 0
#  5 8 6
#
#  3 7 1
#  2 0 4
#  5 8 6
#
#  3 7 1
#  2 8 4
#  5 0 6
#
#  3 7 1
#  2 8 4
#  5 6 0
#
#  3 7 1
#  2 8 4
#  0 5 6
#
#  3 7 1
#  0 2 4
#  5 8 6
#
#  0 7 1
#  3 2 4
#  5 8 6
#
#  3 0 1
#  2 7 4
#  5 8 6
#
#  0 3 1
#  2 7 4
#  5 8 6
#
#  3 7 1
#  5 2 4
#  0 8 6
#
#  2 3 7
#  4 1 0
#  5 8 6
#
#  2 3 0
#  4 1 7
#  5 8 6
#
#  3 7 0
#  8 4 1
#  2 5 6
#
#  4 7 1
#  3 8 6
#  2 5 0
#
#  4 7 1
#  3 8 6
#  2 0 5
#
#  4 7 1
#  3 8 6
#  0 2 5
#
#  4 7 1
#  0 8 6
#  3 2 5
#
#  4 7 1
#  8 0 6
#  3 2 5
#
#  0 7 1
#  4 8 6
#  3 2 5
#
#  4 7 1
#  3 0 6
#  2 8 5
#
#  4 7 1
#  3 6 0
#  2 8 5
#
#  4 7 0
#  3 6 1
#  2 8 5
#
#  4 7 1
#  0 3 6
#  2 8 5
#
#  0 7 1
#  4 3 6
#  2 8 5
#
#  4 0 1
#  3 7 6
#  2 8 5
#
#  0 4 1
#  3 7 6
#  2 8 5
#
#  4 7 1
#  3 6 5
#  2 8 0
#
#  4 7 1
#  2 3 6
#  0 8 5
#
#  4 1 0
#  3 7 6
#  2 8 5
#
#  3 4 7
#  2 1 6
#  5 8 0
#
#  3 4 7
#  2 1 6
#  5 0 8
#
#  3 4 7
#  2 1 6
#  0 5 8
#
#  3 4 7
#  0 1 6
#  2 5 8
#
#  0 4 7
#  3 1 6
#  2 5 8
#
#  3 4 7
#  1 0 6
#  2 5 8
#
#  3 7 1
#  2 4 6
#  5 8 0
#
#  3 7 1
#  2 4 6
#  5 0 8
#
#  3 7 1
#  2 0 6
#  5 4 8
#
#  3 7 1
#  2 4 6
#  0 5 8
#
#  2 3 7
#  4 1 6
#  5 8 0
#
#  3 4 7
#  8 1 0
#  2 5 6
#
#  3 4 0
#  8 1 7
#  2 5 6
#
#  3 0 4
#  8 1 7
#  2 5 6
#
#  0 3 4
#  8 1 7
#  2 5 6
#
#  8 3 4
#  0 1 7
#  2 5 6
#
#  8 3 4
#  2 1 7
#  0 5 6
#
#  8 3 4
#  2 1 7
#  5 0 6
#
#  8 3 4
#  2 0 7
#  5 1 6
#
#  8 0 4
#  2 3 7
#  5 1 6
#
#  0 8 4
#  2 3 7
#  5 1 6
#
#  8 4 0
#  2 3 7
#  5 1 6
#
#  8 3 4
#  0 2 7
#  5 1 6
#
#  0 3 4
#  8 2 7
#  5 1 6
#
#  8 3 4
#  5 2 7
#  0 1 6
#
#  8 3 4
#  2 7 0
#  5 1 6
#
#  8 3 0
#  2 7 4
#  5 1 6
#
#  8 3 4
#  2 1 7
#  5 6 0
#
#  8 3 4
#  2 1 0
#  5 6 7
#
#  8 3 4
#  2 0 1
#  5 6 7
#
#  8 3 0
#  2 1 4
#  5 6 7
#
#  8 3 4
#  2 7 6
#  5 1 0
#
#  8 3 4
#  1 0 7
#  2 5 6
#
#  8 0 4
#  1 3 7
#  2 5 6
#
#  0 8 4
#  1 3 7
#  2 5 6
#
#  1 8 4
#  0 3 7
#  2 5 6
#
#  1 8 4
#  3 0 7
#  2 5 6
#
#  8 4 0
#  1 3 7
#  2 5 6
#
#  8 4 7
#  1 3 0
#  2 5 6
#
#  8 4 7
#  1 0 3
#  2 5 6
#
#  1 8 4
#  2 3 7
#  0 5 6
#
#  8 4 7
#  1 3 6
#  2 5 0
#
#  8 3 4
#  1 5 7
#  2 0 6
#
#  8 3 4
#  1 5 7
#  2 6 0
#
#  8 3 4
#  1 5 0
#  2 6 7
#
#  8 3 4
#  1 0 5
#  2 6 7
#
#  8 3 0
#  1 5 4
#  2 6 7
#
#  8 3 4
#  1 5 7
#  0 2 6
#
#  8 3 4
#  0 5 7
#  1 2 6
#
#  8 3 4
#  5 0 7
#  1 2 6
#
#  0 3 4
#  8 5 7
#  1 2 6
#
#  8 3 4
#  1 7 0
#  2 5 6
#
#  8 3 0
#  1 7 4
#  2 5 6
#
#  8 0 3
#  1 7 4
#  2 5 6
#
#  8 7 3
#  1 0 4
#  2 5 6
#
#  0 8 3
#  1 7 4
#  2 5 6
#
#  3 1 4
#  8 0 7
#  2 5 6
#
#  3 1 4
#  0 8 7
#  2 5 6
#
#  0 1 4
#  3 8 7
#  2 5 6
#
#  1 0 4
#  3 8 7
#  2 5 6
#
#  1 4 0
#  3 8 7
#  2 5 6
#
#  1 4 7
#  3 8 0
#  2 5 6
#
#  1 4 7
#  3 0 8
#  2 5 6
#
#  1 4 7
#  3 8 6
#  2 5 0
#
#  8 3 4
#  1 7 6
#  2 5 0
#
#  8 3 4
#  1 7 6
#  2 0 5
#
#  8 3 4
#  1 7 6
#  0 2 5
#
#  8 3 4
#  1 0 6
#  2 7 5
#
#  3 1 4
#  8 5 7
#  2 0 6
#
#  3 1 4
#  8 5 7
#  2 6 0
#
#  3 1 4
#  8 5 0
#  2 6 7
#
#  3 1 4
#  8 0 5
#  2 6 7
#
#  3 0 4
#  8 1 5
#  2 6 7
#
#  0 3 4
#  8 1 5
#  2 6 7
#
#  3 4 0
#  8 1 5
#  2 6 7
#
#  3 1 4
#  0 8 5
#  2 6 7
#
#  0 1 4
#  3 8 5
#  2 6 7
#
#  3 1 4
#  2 8 5
#  0 6 7
#
#  3 1 4
#  8 6 5
#  2 0 7
#
#  3 1 4
#  8 6 5
#  0 2 7
#
#  3 1 0
#  8 5 4
#  2 6 7
#
#  3 0 1
#  8 5 4
#  2 6 7
#
#  3 5 1
#  8 0 4
#  2 6 7
#
#  0 3 1
#  8 5 4
#  2 6 7
#
#  3 1 4
#  8 6 5
#  2 7 0
#
#  3 1 4
#  8 5 7
#  0 2 6
#
#  3 1 4
#  0 5 7
#  8 2 6
#
#  0 1 4
#  3 5 7
#  8 2 6
#
#  1 0 4
#  3 5 7
#  8 2 6
#
#  1 5 4
#  3 0 7
#  8 2 6
#
#  3 1 4
#  5 0 7
#  8 2 6
#
#  3 0 4
#  5 1 7
#  8 2 6
#
#  0 3 4
#  5 1 7
#  8 2 6
#
#  1 4 0
#  3 5 7
#  8 2 6
#
#  3 1 4
#  5 2 7
#  8 0 6
#
#  3 1 4
#  5 2 7
#  8 6 0
#
#  3 1 4
#  5 7 0
#  8 2 6
#
#  3 1 0
#  5 7 4
#  8 2 6
#
#  3 1 4
#  5 7 6
#  8 2 0
#
#  3 1 4
#  8 7 0
#  2 5 6
#
#  3 1 0
#  8 7 4
#  2 5 6
#
#  3 0 1
#  8 7 4
#  2 5 6
#
#  3 7 1
#  8 0 4
#  2 5 6
#
#  3 7 1
#  0 8 4
#  2 5 6
#
#  0 7 1
#  3 8 4
#  2 5 6
#
#  0 3 1
#  8 7 4
#  2 5 6
#
#  8 3 1
#  0 7 4
#  2 5 6
#
#  8 3 1
#  2 7 4
#  0 5 6
#
#  8 3 1
#  7 0 4
#  2 5 6
#
#  3 7 1
#  8 5 4
#  2 0 6
#
#  3 7 1
#  8 5 4
#  2 6 0
#
#  3 7 1
#  8 5 4
#  0 2 6
#
#  3 7 1
#  8 4 0
#  2 5 6
#
#  3 7 1
#  8 4 6
#  2 5 0
#
#  3 1 4
#  8 7 6
#  2 5 0
#
#  3 1 4
#  8 7 6
#  2 0 5
#
#  3 1 4
#  8 7 6
#  0 2 5
#
#  3 1 4
#  0 7 6
#  8 2 5
#
#  0 1 4
#  3 7 6
#  8 2 5
#
#  3 1 4
#  8 0 6
#  2 7 5
#
#  3 0 4
#  8 1 6
#  2 7 5
#
#  0 3 4
#  8 1 6
#  2 7 5
#
#  3 4 0
#  8 1 6
#  2 7 5
#
#  3 1 4
#  8 6 0
#  2 7 5
#
#  3 1 0
#  8 6 4
#  2 7 5
#
#  3 1 4
#  0 8 6
#  2 7 5
#
#  0 1 4
#  3 8 6
#  2 7 5
#
#  3 1 4
#  7 0 6
#  8 2 5
#
#  3 1 4
#  2 8 6
#  0 7 5
#
#  3 7 1
#  8 4 0
#  2 5 6
#
#  3 4 7
#  8 5 1
#  0 2 6
#
#  3 4 7
#  8 1 6
#  2 5 0
#
#  3 4 7
#  8 1 6
#  2 0 5
#
#  3 4 7
#  8 1 6
#  0 2 5
#
#  3 4 7
#  0 1 6
#  8 2 5
#
#  0 4 7
#  3 1 6
#  8 2 5
#
#  4 0 7
#  3 1 6
#  8 2 5
#
#  4 1 7
#  3 0 6
#  8 2 5
#
#  4 1 7
#  3 6 0
#  8 2 5
#
#  4 1 0
#  3 6 7
#  8 2 5
#
#  4 1 7
#  0 3 6
#  8 2 5
#
#  4 1 7
#  8 3 6
#  0 2 5
#
#  0 1 7
#  4 3 6
#  8 2 5
#
#  4 7 0
#  3 1 6
#  8 2 5
#
#  4 7 6
#  3 1 0
#  8 2 5
#
#  4 7 6
#  3 0 1
#  8 2 5
#
#  4 1 7
#  3 6 5
#  8 2 0
#
#  4 7 6
#  3 1 5
#  8 2 0
#
#  4 1 7
#  3 2 6
#  8 0 5
#
#  4 1 7
#  3 2 6
#  0 8 5
#
#  3 4 7
#  1 0 6
#  8 2 5
#
#  3 4 7
#  1 6 0
#  8 2 5
#
#  3 4 0
#  1 6 7
#  8 2 5
#
#  3 0 4
#  1 6 7
#  8 2 5
#
#  3 6 4
#  1 0 7
#  8 2 5
#
#  0 3 4
#  1 6 7
#  8 2 5
#
#  3 0 7
#  1 4 6
#  8 2 5
#
#  0 3 7
#  1 4 6
#  8 2 5
#
#  1 3 7
#  0 4 6
#  8 2 5
#
#  1 3 7
#  8 4 6
#  0 2 5
#
#  4 1 7
#  3 2 6
#  8 5 0
#
#  3 4 7
#  1 6 5
#  8 2 0
#
#  3 4 7
#  1 6 5
#  8 0 2
#
#  3 4 7
#  1 0 5
#  8 6 2
#
#  3 4 7
#  1 6 5
#  0 8 2
#
#  3 7 0
#  1 4 6
#  8 2 5
#
#  3 7 6
#  1 4 0
#  8 2 5
#
#  3 7 6
#  1 0 4
#  8 2 5
#
#  1 3 7
#  4 0 6
#  8 2 5
#
#  3 7 6
#  1 4 5
#  8 2 0
#
#  3 4 7
#  1 2 6
#  8 0 5
#
#  3 4 7
#  1 2 6
#  0 8 5
#
#  3 4 7
#  0 2 6
#  1 8 5
#
#  0 4 7
#  3 2 6
#  1 8 5
#
#  3 4 7
#  2 0 6
#  1 8 5
#
#  3 4 7
#  1 2 6
#  8 5 0
#
#  3 4 7
#  1 2 0
#  8 5 6
#
#  3 4 7
#  1 0 2
#  8 5 6
#
#  3 4 0
#  1 2 7
#  8 5 6
#
#  3 5 4
#  8 6 7
#  2 0 1
#
#  3 5 4
#  8 6 7
#  0 2 1
#
#  3 5 4
#  0 6 7
#  8 2 1
#
#  0 5 4
#  3 6 7
#  8 2 1
#
#  5 0 4
#  3 6 7
#  8 2 1
#
#  5 6 4
#  3 0 7
#  8 2 1
#
#  5 6 4
#  0 3 7
#  8 2 1
#
#  5 6 4
#  8 3 7
#  0 2 1
#
#  5 6 4
#  8 3 7
#  2 0 1
#
#  5 6 4
#  8 0 7
#  2 3 1
#
#  5 6 4
#  0 8 7
#  2 3 1
#
#  0 6 4
#  5 8 7
#  2 3 1
#
#  6 0 4
#  5 8 7
#  2 3 1
#
#  6 8 4
#  5 0 7
#  2 3 1
#
#  6 8 4
#  0 5 7
#  2 3 1
#
#  0 8 4
#  6 5 7
#  2 3 1
#
#  6 8 4
#  2 5 7
#  0 3 1
#
#  6 8 4
#  5 3 7
#  2 0 1
#
#  6 8 4
#  5 3 7
#  0 2 1
#
#  6 8 4
#  5 7 0
#  2 3 1
#
#  6 8 0
#  5 7 4
#  2 3 1
#
#  6 4 0
#  5 8 7
#  2 3 1
#
#  6 4 7
#  5 8 0
#  2 3 1
#
#  6 4 7
#  5 0 8
#  2 3 1
#
#  6 8 4
#  5 3 7
#  2 1 0
#
#  6 8 4
#  5 7 1
#  2 3 0
#
#  6 4 7
#  5 8 1
#  2 3 0
#
#  5 0 4
#  8 6 7
#  2 3 1
#
#  0 5 4
#  8 6 7
#  2 3 1
#
#  8 5 4
#  0 6 7
#  2 3 1
#
#  8 5 4
#  6 0 7
#  2 3 1
#
#  8 0 4
#  6 5 7
#  2 3 1
#
#  8 4 0
#  6 5 7
#  2 3 1
#
#  8 5 4
#  6 3 7
#  2 0 1
#
#  8 5 4
#  6 3 7
#  0 2 1
#
#  8 5 4
#  6 7 0
#  2 3 1
#
#  8 5 0
#  6 7 4
#  2 3 1
#
#  8 5 4
#  2 6 7
#  0 3 1
#
#  8 5 4
#  2 6 7
#  3 0 1
#
#  8 5 4
#  2 0 7
#  3 6 1
#
#  8 5 4
#  6 3 7
#  2 1 0
#
#  8 5 4
#  6 7 1
#  2 3 0
#
#  8 5 4
#  2 6 7
#  3 1 0
#
#  5 6 4
#  2 8 7
#  0 3 1
#
#  5 6 4
#  2 8 7
#  3 0 1
#
#  5 6 4
#  2 0 7
#  3 8 1
#
#  5 6 4
#  0 2 7
#  3 8 1
#
#  0 6 4
#  5 2 7
#  3 8 1
#
#  5 0 4
#  2 6 7
#  3 8 1
#
#  0 5 4
#  2 6 7
#  3 8 1
#
#  5 6 4
#  3 2 7
#  0 8 1
#
#  5 4 0
#  2 6 7
#  3 8 1
#
#  5 6 4
#  2 7 0
#  3 8 1
#
#  5 6 0
#  2 7 4
#  3 8 1
#
#  5 4 0
#  8 6 7
#  2 3 1
#
#  5 4 7
#  8 6 0
#  2 3 1
#
#  5 4 7
#  8 0 6
#  2 3 1
#
#  5 4 7
#  0 8 6
#  2 3 1
#
#  0 4 7
#  5 8 6
#  2 3 1
#
#  5 0 7
#  8 4 6
#  2 3 1
#
#  0 5 7
#  8 4 6
#  2 3 1
#
#  5 4 7
#  2 8 6
#  0 3 1
#
#  5 7 0
#  8 4 6
#  2 3 1
#
#  5 4 7
#  8 3 6
#  2 0 1
#
#  5 4 7
#  8 3 6
#  0 2 1
#
#  5 6 4
#  2 8 7
#  3 1 0
#
#  5 6 4
#  2 8 0
#  3 1 7
#
#  5 6 4
#  2 0 8
#  3 1 7
#
#  5 6 0
#  2 8 4
#  3 1 7
#
#  5 6 4
#  2 7 1
#  3 8 0
#
#  5 4 7
#  8 6 1
#  2 3 0
#
#  5 4 7
#  8 6 1
#  2 0 3
#
#  5 4 7
#  8 0 1
#  2 6 3
#
#  5 4 7
#  8 6 1
#  0 2 3
#
#  5 4 7
#  8 3 6
#  2 1 0
#
#  5 6 4
#  8 7 0
#  2 3 1
#
#  5 6 0
#  8 7 4
#  2 3 1
#
#  5 0 6
#  8 7 4
#  2 3 1
#
#  5 7 6
#  8 0 4
#  2 3 1
#
#  5 7 6
#  0 8 4
#  2 3 1
#
#  0 7 6
#  5 8 4
#  2 3 1
#
#  0 5 6
#  8 7 4
#  2 3 1
#
#  8 5 6
#  0 7 4
#  2 3 1
#
#  5 7 6
#  2 8 4
#  0 3 1
#
#  8 5 6
#  2 7 4
#  0 3 1
#
#  8 5 6
#  7 0 4
#  2 3 1
#
#  5 7 6
#  8 3 4
#  2 0 1
#
#  5 7 6
#  8 3 4
#  0 2 1
#
#  5 7 6
#  8 4 0
#  2 3 1
#
#  5 7 6
#  8 3 4
#  2 1 0
#
#  5 7 6
#  8 4 1
#  2 3 0
#
#  5 6 4
#  8 7 1
#  2 3 0
#
#  5 6 4
#  8 7 1
#  2 0 3
#
#  5 6 4
#  8 7 1
#  0 2 3
#
#  5 6 4
#  0 7 1
#  8 2 3
#
#  0 6 4
#  5 7 1
#  8 2 3
#
#  5 6 4
#  8 0 1
#  2 7 3
#
#  5 6 4
#  0 8 1
#  2 7 3
#
#  0 6 4
#  5 8 1
#  2 7 3
#
#  5 0 4
#  8 6 1
#  2 7 3
#
#  0 5 4
#  8 6 1
#  2 7 3
#
#  5 6 4
#  7 0 1
#  8 2 3
#
#  5 6 4
#  2 8 1
#  0 7 3
#
#  5 4 0
#  8 6 1
#  2 7 3
#
#  5 6 4
#  8 1 0
#  2 7 3
#
#  5 6 0
#  8 1 4
#  2 7 3
#
#  5 6 4
#  8 1 3
#  2 7 0
#
#  0 6 4
#  5 3 7
#  8 2 1
#
#  6 0 4
#  5 3 7
#  8 2 1
#
#  5 6 4
#  8 3 7
#  2 1 0
#
#  5 6 4
#  8 3 0
#  2 1 7
#
#  5 6 4
#  8 0 3
#  2 1 7
#
#  5 6 4
#  0 8 3
#  2 1 7
#
#  0 6 4
#  5 8 3
#  2 1 7
#
#  6 0 4
#  5 8 3
#  2 1 7
#
#  6 8 4
#  5 0 3
#  2 1 7
#
#  6 4 0
#  5 8 3
#  2 1 7
#
#  5 0 4
#  8 6 3
#  2 1 7
#
#  0 5 4
#  8 6 3
#  2 1 7
#
#  8 5 4
#  0 6 3
#  2 1 7
#
#  8 5 4
#  6 0 3
#  2 1 7
#
#  8 5 4
#  2 6 3
#  0 1 7
#
#  5 6 0
#  8 3 4
#  2 1 7
#
#  5 0 6
#  8 3 4
#  2 1 7
#
#  0 5 6
#  8 3 4
#  2 1 7
#
#  8 5 6
#  0 3 4
#  2 1 7
#
#  8 5 6
#  3 0 4
#  2 1 7
#
#  8 5 6
#  2 3 4
#  0 1 7
#
#  5 6 4
#  2 8 3
#  0 1 7
#
#  5 4 0
#  8 6 3
#  2 1 7
#
#  5 3 6
#  8 0 4
#  2 1 7
#
#  5 3 6
#  0 8 4
#  2 1 7
#
#  0 3 6
#  5 8 4
#  2 1 7
#
#  5 3 6
#  2 8 4
#  0 1 7
#
#  5 6 4
#  8 1 3
#  2 0 7
#
#  5 6 4
#  8 1 3
#  0 2 7
#
#  5 6 4
#  0 1 3
#  8 2 7
#
#  0 6 4
#  5 1 3
#  8 2 7
#
#  5 6 4
#  1 0 3
#  8 2 7
#
#  5 6 4
#  2 8 3
#  1 0 7
#
#  5 6 4
#  2 0 3
#  1 8 7
#
#  5 4 3
#  8 6 0
#  2 1 7
#
#  5 4 3
#  8 6 7
#  2 1 0
#
#  5 4 3
#  8 0 6
#  2 1 7
#
#  5 3 6
#  8 1 4
#  2 0 7
#
#  5 3 6
#  8 1 4
#  0 2 7
#
#  5 3 6
#  8 4 0
#  2 1 7
#
#  5 3 6
#  8 4 7
#  2 1 0
#
#  5 3 0
#  8 4 6
#  2 1 7
#
#  6 3 4
#  5 0 7
#  8 2 1
#
#  6 3 4
#  0 5 7
#  8 2 1
#
#  6 3 4
#  8 5 7
#  0 2 1
#
#  6 3 4
#  8 5 7
#  2 0 1
#
#  6 3 4
#  8 0 7
#  2 5 1
#
#  6 0 4
#  8 3 7
#  2 5 1
#
#  0 6 4
#  8 3 7
#  2 5 1
#
#  6 4 0
#  8 3 7
#  2 5 1
#
#  6 3 4
#  0 8 7
#  2 5 1
#
#  0 3 4
#  6 8 7
#  2 5 1
#
#  6 3 4
#  2 8 7
#  0 5 1
#
#  6 3 4
#  8 7 0
#  2 5 1
#
#  6 3 0
#  8 7 4
#  2 5 1
#
#  6 3 4
#  8 7 1
#  2 5 0
#
#  6 3 4
#  8 5 7
#  2 1 0
#
#  6 3 4
#  8 5 0
#  2 1 7
#
#  6 3 4
#  8 0 5
#  2 1 7
#
#  6 3 0
#  8 5 4
#  2 1 7
#
#  6 4 0
#  5 3 7
#  8 2 1
#
#  6 4 7
#  5 3 0
#  8 2 1
#
#  6 4 7
#  5 0 3
#  8 2 1
#
#  6 4 7
#  0 5 3
#  8 2 1
#
#  6 4 7
#  8 5 3
#  0 2 1
#
#  6 4 7
#  8 5 3
#  2 0 1
#
#  6 4 7
#  8 0 3
#  2 5 1
#
#  0 4 7
#  6 5 3
#  8 2 1
#
#  6 4 7
#  8 5 3
#  2 1 0
#
#  6 0 7
#  5 4 3
#  8 2 1
#
#  0 6 7
#  5 4 3
#  8 2 1
#
#  5 6 7
#  0 4 3
#  8 2 1
#
#  5 6 7
#  8 4 3
#  0 2 1
#
#  5 6 7
#  4 0 3
#  8 2 1
#
#  4 0 7
#  6 5 3
#  8 2 1
#
#  4 5 7
#  6 0 3
#  8 2 1
#
#  6 7 0
#  5 4 3
#  8 2 1
#
#  4 7 0
#  6 5 3
#  8 2 1
#
#  6 4 7
#  5 2 3
#  8 0 1
#
#  6 4 7
#  5 2 3
#  0 8 1
#
#  6 4 7
#  0 2 3
#  5 8 1
#
#  6 4 7
#  2 0 3
#  5 8 1
#
#  0 4 7
#  6 2 3
#  5 8 1
#
#  6 7 3
#  5 4 0
#  8 2 1
#
#  6 7 3
#  5 0 4
#  8 2 1
#
#  5 6 4
#  2 8 3
#  1 7 0
#
#  5 3 6
#  8 1 4
#  2 7 0
#
#  6 4 7
#  5 3 1
#  8 2 0
#
#  6 4 7
#  5 3 1
#  8 0 2
#
#  6 4 7
#  5 0 1
#  8 3 2
#
#  6 4 7
#  0 5 1
#  8 3 2
#
#  6 4 7
#  8 5 1
#  0 3 2
#
#  0 4 7
#  6 5 1
#  8 3 2
#
#  6 0 7
#  5 4 1
#  8 3 2
#
#  0 6 7
#  5 4 1
#  8 3 2
#
#  6 7 0
#  5 4 1
#  8 3 2
#
#  6 4 7
#  5 1 0
#  8 3 2
#
#  6 4 0
#  5 1 7
#  8 3 2
#
#  6 4 7
#  5 3 1
#  0 8 2
#
#  6 4 7
#  0 3 1
#  5 8 2
#
#  6 4 7
#  3 0 1
#  5 8 2
#
#  0 4 7
#  6 3 1
#  5 8 2
#
#  6 4 7
#  5 1 2
#  8 3 0
#
#  6 4 7
#  5 2 3
#  8 1 0
#
#  6 4 7
#  5 2 0
#  8 1 3
#
#  6 4 7
#  5 0 2
#  8 1 3
#
#  6 4 0
#  5 2 7
#  8 1 3
#
#  6 7 3
#  5 4 1
#  8 2 0
#
#  6 3 4
#  5 2 7
#  8 0 1
#
#  6 3 4
#  5 2 7
#  0 8 1
#
#  6 3 4
#  0 2 7
#  5 8 1
#
#  6 3 4
#  2 0 7
#  5 8 1
#
#  6 0 4
#  2 3 7
#  5 8 1
#
#  0 6 4
#  2 3 7
#  5 8 1
#
#  6 4 0
#  2 3 7
#  5 8 1
#
#  6 3 4
#  2 8 7
#  5 0 1
#
#  0 3 4
#  6 2 7
#  5 8 1
#
#  3 0 4
#  6 2 7
#  5 8 1
#
#  6 3 4
#  2 8 7
#  5 1 0
#
#  3 2 4
#  6 0 7
#  5 8 1
#
#  3 4 0
#  6 2 7
#  5 8 1
#
#  6 3 4
#  2 7 0
#  5 8 1
#
#  6 3 0
#  2 7 4
#  5 8 1
#
#  6 3 4
#  2 7 1
#  5 8 0
#
#  6 3 4
#  5 7 0
#  8 2 1
#
#  6 3 0
#  5 7 4
#  8 2 1
#
#  6 0 3
#  5 7 4
#  8 2 1
#
#  0 6 3
#  5 7 4
#  8 2 1
#
#  5 6 3
#  0 7 4
#  8 2 1
#
#  5 6 3
#  8 7 4
#  0 2 1
#
#  5 6 3
#  7 0 4
#  8 2 1
#
#  6 3 4
#  5 2 7
#  8 1 0
#
#  6 3 4
#  5 2 0
#  8 1 7
#
#  6 3 4
#  5 0 2
#  8 1 7
#
#  6 0 4
#  5 3 2
#  8 1 7
#
#  0 6 4
#  5 3 2
#  8 1 7
#
#  6 4 0
#  5 3 2
#  8 1 7
#
#  6 3 4
#  0 5 2
#  8 1 7
#
#  6 3 4
#  8 5 2
#  0 1 7
#
#  0 3 4
#  6 5 2
#  8 1 7
#
#  6 3 4
#  5 1 2
#  8 0 7
#
#  6 3 4
#  5 1 2
#  0 8 7
#
#  6 3 0
#  5 2 4
#  8 1 7
#
#  6 0 3
#  5 2 4
#  8 1 7
#
#  0 6 3
#  5 2 4
#  8 1 7
#
#  6 3 4
#  5 1 2
#  8 7 0
#
#  6 2 3
#  5 0 4
#  8 1 7
#
#  6 3 4
#  5 7 1
#  8 2 0
#
#  6 3 4
#  5 7 1
#  8 0 2
#
#  6 3 4
#  5 7 1
#  0 8 2
#
#  6 3 4
#  0 7 1
#  5 8 2
#
#  0 3 4
#  6 7 1
#  5 8 2
#
#  6 3 4
#  7 0 1
#  5 8 2
#
#  6 3 4
#  5 0 1
#  8 7 2
#
#  6 0 4
#  5 3 1
#  8 7 2
#
#  0 6 4
#  5 3 1
#  8 7 2
#
#  6 4 0
#  5 3 1
#  8 7 2
#
#  6 3 4
#  0 5 1
#  8 7 2
#
#  6 3 4
#  8 5 1
#  0 7 2
#
#  0 3 4
#  6 5 1
#  8 7 2
#
#  6 3 4
#  5 1 0
#  8 7 2
#
#  6 3 0
#  5 1 4
#  8 7 2
#
#  5 6 4
#  3 2 7
#  8 0 1
#
#  5 6 4
#  3 7 0
#  8 2 1
#
#  5 6 0
#  3 7 4
#  8 2 1
#
#  5 0 6
#  3 7 4
#  8 2 1
#
#  5 7 6
#  3 0 4
#  8 2 1
#
#  5 7 6
#  0 3 4
#  8 2 1
#
#  0 7 6
#  5 3 4
#  8 2 1
#
#  7 0 6
#  5 3 4
#  8 2 1
#
#  7 6 0
#  5 3 4
#  8 2 1
#
#  7 6 4
#  5 3 0
#  8 2 1
#
#  7 6 4
#  5 0 3
#  8 2 1
#
#  7 6 4
#  5 3 1
#  8 2 0
#
#  0 5 6
#  3 7 4
#  8 2 1
#
#  7 3 6
#  5 0 4
#  8 2 1
#
#  7 3 6
#  0 5 4
#  8 2 1
#
#  7 3 6
#  8 5 4
#  0 2 1
#
#  0 3 6
#  7 5 4
#  8 2 1
#
#  5 7 6
#  3 2 4
#  8 0 1
#
#  5 7 6
#  3 2 4
#  0 8 1
#
#  5 7 6
#  0 2 4
#  3 8 1
#
#  5 7 6
#  2 0 4
#  3 8 1
#
#  5 7 6
#  2 8 4
#  3 0 1
#
#  5 0 6
#  2 7 4
#  3 8 1
#
#  0 5 6
#  2 7 4
#  3 8 1
#
#  0 7 6
#  5 2 4
#  3 8 1
#
#  5 7 6
#  2 8 4
#  3 1 0
#
#  5 7 6
#  2 4 0
#  3 8 1
#
#  5 7 0
#  2 4 6
#  3 8 1
#
#  7 0 6
#  5 2 4
#  3 8 1
#
#  7 6 0
#  5 2 4
#  3 8 1
#
#  5 7 6
#  2 4 1
#  3 8 0
#
#  7 2 6
#  5 0 4
#  3 8 1
#
#  5 7 6
#  3 4 0
#  8 2 1
#
#  5 7 0
#  3 4 6
#  8 2 1
#
#  5 0 7
#  3 4 6
#  8 2 1
#
#  5 4 7
#  3 0 6
#  8 2 1
#
#  5 4 7
#  3 6 0
#  8 2 1
#
#  5 4 0
#  3 6 7
#  8 2 1
#
#  5 4 7
#  0 3 6
#  8 2 1
#
#  0 4 7
#  5 3 6
#  8 2 1
#
#  0 5 7
#  3 4 6
#  8 2 1
#
#  5 4 7
#  3 6 1
#  8 2 0
#
#  5 4 7
#  3 2 6
#  8 0 1
#
#  5 4 7
#  3 2 6
#  0 8 1
#
#  3 5 7
#  0 4 6
#  8 2 1
#
#  3 5 7
#  8 4 6
#  0 2 1
#
#  5 4 7
#  3 2 6
#  8 1 0
#
#  3 5 7
#  4 0 6
#  8 2 1
#
#  3 5 6
#  0 7 4
#  8 2 1
#
#  3 5 6
#  8 7 4
#  0 2 1
#
#  3 5 6
#  8 7 4
#  2 0 1
#
#  3 5 6
#  8 0 4
#  2 7 1
#
#  3 5 6
#  0 8 4
#  2 7 1
#
#  0 5 6
#  3 8 4
#  2 7 1
#
#  3 0 6
#  8 5 4
#  2 7 1
#
#  3 6 0
#  8 5 4
#  2 7 1
#
#  0 3 6
#  8 5 4
#  2 7 1
#
#  3 5 6
#  2 8 4
#  0 7 1
#
#  3 5 6
#  8 4 0
#  2 7 1
#
#  3 5 0
#  8 4 6
#  2 7 1
#
#  3 5 6
#  8 7 4
#  2 1 0
#
#  3 5 6
#  8 7 0
#  2 1 4
#
#  3 5 6
#  8 0 7
#  2 1 4
#
#  3 5 0
#  8 7 6
#  2 1 4
#
#  3 5 6
#  8 4 1
#  2 7 0
#
#  7 3 6
#  5 2 4
#  8 0 1
#
#  7 3 6
#  5 2 4
#  0 8 1
#
#  7 3 6
#  5 4 0
#  8 2 1
#
#  7 3 0
#  5 4 6
#  8 2 1
#
#  5 7 6
#  3 2 4
#  8 1 0
#
#  5 7 6
#  3 2 0
#  8 1 4
#
#  5 7 6
#  3 0 2
#  8 1 4
#
#  5 7 6
#  0 3 2
#  8 1 4
#
#  5 7 6
#  8 3 2
#  0 1 4
#
#  0 7 6
#  5 3 2
#  8 1 4
#
#  5 0 6
#  3 7 2
#  8 1 4
#
#  5 6 0
#  3 7 2
#  8 1 4
#
#  0 5 6
#  3 7 2
#  8 1 4
#
#  5 7 6
#  3 1 2
#  8 0 4
#
#  5 7 6
#  3 1 2
#  0 8 4
#
#  5 7 0
#  3 2 6
#  8 1 4
#
#  5 0 7
#  3 2 6
#  8 1 4
#
#  0 5 7
#  3 2 6
#  8 1 4
#
#  5 2 7
#  3 0 6
#  8 1 4
#
#  5 7 6
#  3 1 2
#  8 4 0
#
#  5 7 6
#  3 4 1
#  8 2 0
#
#  5 7 6
#  3 4 1
#  8 0 2
#
#  5 7 6
#  3 0 1
#  8 4 2
#
#  5 7 6
#  0 3 1
#  8 4 2
#
#  5 7 6
#  8 3 1
#  0 4 2
#
#  0 7 6
#  5 3 1
#  8 4 2
#
#  5 0 6
#  3 7 1
#  8 4 2
#
#  5 6 0
#  3 7 1
#  8 4 2
#
#  0 5 6
#  3 7 1
#  8 4 2
#
#  5 7 6
#  3 1 0
#  8 4 2
#
#  5 7 0
#  3 1 6
#  8 4 2
#
#  5 7 6
#  3 4 1
#  0 8 2
#
#  5 7 6
#  0 4 1
#  3 8 2
#
#  0 7 6
#  5 4 1
#  3 8 2
#
#  5 7 6
#  4 0 1
#  3 8 2
#
#  3 5 6
#  7 0 4
#  8 2 1
#
#  3 0 6
#  7 5 4
#  8 2 1
#
#  3 6 0
#  7 5 4
#  8 2 1
#
#  3 6 4
#  7 5 0
#  8 2 1
#
#  3 6 4
#  7 0 5
#  8 2 1
#
#  3 6 4
#  7 5 1
#  8 2 0
#
#  7 3 6
#  5 2 4
#  8 1 0
#
#  7 3 6
#  5 4 1
#  8 2 0
#
#  3 5 6
#  7 2 4
#  8 0 1
#
#  3 5 6
#  7 2 4
#  0 8 1
#
#  3 5 6
#  0 2 4
#  7 8 1
#
#  0 5 6
#  3 2 4
#  7 8 1
#
#  3 5 6
#  2 0 4
#  7 8 1
#
#  3 5 6
#  7 4 0
#  8 2 1
#
#  3 5 0
#  7 4 6
#  8 2 1
#
#  3 0 5
#  7 4 6
#  8 2 1
#
#  3 4 5
#  7 0 6
#  8 2 1
#
#  0 3 5
#  7 4 6
#  8 2 1
#
#  5 4 0
#  3 6 7
#  8 2 1
#
#  5 6 4
#  3 2 7
#  8 1 0
#
#  5 6 4
#  3 2 0
#  8 1 7
#
#  5 6 4
#  3 0 2
#  8 1 7
#
#  5 6 4
#  0 3 2
#  8 1 7
#
#  5 6 4
#  8 3 2
#  0 1 7
#
#  5 0 4
#  3 6 2
#  8 1 7
#
#  0 5 4
#  3 6 2
#  8 1 7
#
#  5 6 4
#  8 3 2
#  1 0 7
#
#  5 6 4
#  8 0 2
#  1 3 7
#
#  5 6 4
#  0 8 2
#  1 3 7
#
#  0 6 4
#  5 8 2
#  1 3 7
#
#  5 0 4
#  8 6 2
#  1 3 7
#
#  0 5 4
#  8 6 2
#  1 3 7
#
#  5 6 4
#  1 8 2
#  0 3 7
#
#  5 4 0
#  8 6 2
#  1 3 7
#
#  5 6 4
#  8 2 0
#  1 3 7
#
#  5 6 4
#  8 2 7
#  1 3 0
#
#  5 6 0
#  8 2 4
#  1 3 7
#
#  3 5 4
#  0 6 2
#  8 1 7
#
#  3 5 4
#  8 6 2
#  0 1 7
#
#  3 5 4
#  6 0 2
#  8 1 7
#
#  3 0 4
#  6 5 2
#  8 1 7
#
#  3 4 0
#  6 5 2
#  8 1 7
#
#  3 5 4
#  8 6 2
#  1 0 7
#
#  3 5 4
#  8 0 2
#  1 6 7
#
#  3 5 4
#  6 1 2
#  8 0 7
#
#  3 5 4
#  6 1 2
#  0 8 7
#
#  3 5 4
#  6 2 0
#  8 1 7
#
#  3 5 4
#  6 2 7
#  8 1 0
#
#  3 5 0
#  6 2 4
#  8 1 7
#
#  5 4 0
#  3 6 2
#  8 1 7
#
#  5 6 4
#  8 3 2
#  1 7 0
#
#  5 6 4
#  8 3 0
#  1 7 2
#
#  5 6 4
#  8 0 3
#  1 7 2
#
#  5 6 0
#  8 3 4
#  1 7 2
#
#  3 5 4
#  8 6 2
#  1 7 0
#
#  3 5 4
#  6 1 2
#  8 7 0
#
#  5 6 4
#  3 1 2
#  8 0 7
#
#  5 6 4
#  3 1 2
#  0 8 7
#
#  5 6 4
#  0 1 2
#  3 8 7
#
#  0 6 4
#  5 1 2
#  3 8 7
#
#  6 0 4
#  5 1 2
#  3 8 7
#
#  6 1 4
#  5 0 2
#  3 8 7
#
#  6 4 0
#  5 1 2
#  3 8 7
#
#  5 6 4
#  1 0 2
#  3 8 7
#
#  5 6 4
#  1 8 2
#  3 0 7
#
#  5 0 4
#  1 6 2
#  3 8 7
#
#  0 5 4
#  1 6 2
#  3 8 7
#
#  5 6 4
#  1 8 2
#  3 7 0
#
#  5 4 0
#  1 6 2
#  3 8 7
#
#  5 6 4
#  1 2 0
#  3 8 7
#
#  5 6 4
#  1 2 7
#  3 8 0
#
#  5 6 0
#  1 2 4
#  3 8 7
#
#  5 4 2
#  3 6 0
#  8 1 7
#
#  5 4 2
#  3 6 7
#  8 1 0
#
#  5 4 2
#  3 6 7
#  8 0 1
#
#  5 4 2
#  3 0 7
#  8 6 1
#
#  5 4 2
#  3 6 7
#  0 8 1
#
#  5 4 2
#  3 0 6
#  8 1 7
#
#  5 4 2
#  0 3 6
#  8 1 7
#
#  5 4 2
#  8 3 6
#  0 1 7
#
#  0 4 2
#  5 3 6
#  8 1 7
#
#  5 0 2
#  3 4 6
#  8 1 7
#
#  0 5 2
#  3 4 6
#  8 1 7
#
#  5 2 0
#  3 4 6
#  8 1 7
#
#  5 4 2
#  3 1 6
#  8 0 7
#
#  5 4 2
#  3 1 6
#  0 8 7
#
#  5 6 0
#  3 2 4
#  8 1 7
#
#  5 0 6
#  3 2 4
#  8 1 7
#
#  0 5 6
#  3 2 4
#  8 1 7
#
#  3 5 6
#  0 2 4
#  8 1 7
#
#  3 5 6
#  8 2 4
#  0 1 7
#
#  3 5 6
#  2 0 4
#  8 1 7
#
#  3 0 6
#  2 5 4
#  8 1 7
#
#  3 6 0
#  2 5 4
#  8 1 7
#
#  0 3 6
#  2 5 4
#  8 1 7
#
#  3 5 6
#  8 2 4
#  1 0 7
#
#  3 5 6
#  8 0 4
#  1 2 7
#
#  3 5 6
#  2 1 4
#  8 0 7
#
#  3 5 6
#  2 1 4
#  0 8 7
#
#  3 5 6
#  2 4 0
#  8 1 7
#
#  3 5 6
#  2 4 7
#  8 1 0
#
#  3 5 0
#  2 4 6
#  8 1 7
#
#  5 6 4
#  3 1 2
#  8 7 0
#
#  5 6 4
#  3 1 0
#  8 7 2
#
#  5 6 4
#  3 0 1
#  8 7 2
#
#  5 6 4
#  3 7 1
#  8 0 2
#
#  5 6 4
#  3 7 1
#  0 8 2
#
#  5 6 4
#  0 3 1
#  8 7 2
#
#  5 6 4
#  8 3 1
#  0 7 2
#
#  5 0 4
#  3 6 1
#  8 7 2
#
#  0 5 4
#  3 6 1
#  8 7 2
#
#  5 6 4
#  3 7 1
#  8 2 0
#
#  5 4 0
#  3 6 1
#  8 7 2
#
#  5 6 0
#  3 1 4
#  8 7 2
#
#  5 0 6
#  3 1 4
#  8 7 2
#
#  0 5 6
#  3 1 4
#  8 7 2
#
#  5 1 6
#  3 0 4
#  8 7 2
#
#  5 4 2
#  3 1 6
#  8 7 0
#
#  5 2 6
#  3 0 4
#  8 1 7
#
#  5 2 6
#  0 3 4
#  8 1 7
#
#  5 2 6
#  8 3 4
#  0 1 7
#
#  0 2 6
#  5 3 4
#  8 1 7
#
#  2 0 6
#  5 3 4
#  8 1 7
#
#  2 6 0
#  5 3 4
#  8 1 7
#
#  2 3 6
#  5 0 4
#  8 1 7
#
#  5 2 6
#  8 3 4
#  1 0 7
#
#  5 2 6
#  8 0 4
#  1 3 7
#
#  3 5 6
#  8 2 4
#  1 7 0
#
#  3 5 6
#  2 1 4
#  8 7 0
#
#  5 2 6
#  8 3 4
#  1 7 0
#
#  5 2 6
#  3 1 4
#  8 0 7
#
#  5 2 6
#  3 1 4
#  0 8 7
#
#  5 2 6
#  0 1 4
#  3 8 7
#
#  0 2 6
#  5 1 4
#  3 8 7
#
#  5 2 6
#  1 0 4
#  3 8 7
#
#  5 2 6
#  3 4 0
#  8 1 7
#
#  5 2 6
#  3 4 7
#  8 1 0
#
#  5 2 6
#  3 4 7
#  8 0 1
#
#  5 2 6
#  3 0 7
#  8 4 1
#
#  5 2 6
#  3 4 7
#  0 8 1
#
#  5 6 4
#  3 7 1
#  8 2 0
#
#  3 5 6
#  7 2 4
#  8 1 0
#
#  3 5 6
#  7 2 0
#  8 1 4
#
#  3 5 6
#  7 0 2
#  8 1 4
#
#  3 5 0
#  7 2 6
#  8 1 4
#
#  3 5 6
#  7 4 1
#  8 2 0
#
#  3 5 6
#  7 4 1
#  8 0 2
#
#  3 5 6
#  7 0 1
#  8 4 2
#
#  3 5 6
#  7 4 1
#  0 8 2
#
#  5 2 6
#  3 1 4
#  8 7 0
#
#  5 2 6
#  3 1 0
#  8 7 4
#
#  5 2 6
#  3 0 1
#  8 7 4
#
#  5 2 0
#  3 1 6
#  8 7 4
#
#  3 5 4
#  8 7 0
#  2 6 1
#
#  3 5 0
#  8 7 4
#  2 6 1
#
#  3 0 5
#  8 7 4
#  2 6 1
#
#  0 3 5
#  8 7 4
#  2 6 1
#
#  8 3 5
#  0 7 4
#  2 6 1
#
#  8 3 5
#  2 7 4
#  0 6 1
#
#  8 3 5
#  2 7 4
#  6 0 1
#
#  8 3 5
#  2 0 4
#  6 7 1
#
#  8 0 5
#  2 3 4
#  6 7 1
#
#  0 8 5
#  2 3 4
#  6 7 1
#
#  2 8 5
#  0 3 4
#  6 7 1
#
#  2 8 5
#  3 0 4
#  6 7 1
#
#  2 8 5
#  3 7 4
#  6 0 1
#
#  2 8 5
#  3 7 4
#  0 6 1
#
#  2 8 5
#  0 7 4
#  3 6 1
#
#  0 8 5
#  2 7 4
#  3 6 1
#
#  2 8 5
#  7 0 4
#  3 6 1
#
#  2 0 5
#  3 8 4
#  6 7 1
#
#  0 2 5
#  3 8 4
#  6 7 1
#
#  3 2 5
#  0 8 4
#  6 7 1
#
#  3 2 5
#  8 0 4
#  6 7 1
#
#  2 8 5
#  3 7 4
#  6 1 0
#
#  2 8 5
#  3 7 0
#  6 1 4
#
#  2 8 5
#  3 0 7
#  6 1 4
#
#  2 8 0
#  3 7 5
#  6 1 4
#
#  2 5 0
#  3 8 4
#  6 7 1
#
#  2 5 4
#  3 8 0
#  6 7 1
#
#  2 5 4
#  3 0 8
#  6 7 1
#
#  3 2 5
#  6 8 4
#  0 7 1
#
#  2 5 4
#  3 8 1
#  6 7 0
#
#  2 8 5
#  3 4 0
#  6 7 1
#
#  2 8 0
#  3 4 5
#  6 7 1
#
#  2 0 8
#  3 4 5
#  6 7 1
#
#  2 4 8
#  3 0 5
#  6 7 1
#
#  0 2 8
#  3 4 5
#  6 7 1
#
#  8 5 0
#  2 3 4
#  6 7 1
#
#  8 5 4
#  2 3 0
#  6 7 1
#
#  8 5 4
#  2 0 3
#  6 7 1
#
#  8 5 4
#  2 7 3
#  6 0 1
#
#  8 5 4
#  2 7 3
#  0 6 1
#
#  8 5 4
#  0 7 3
#  2 6 1
#
#  0 5 4
#  8 7 3
#  2 6 1
#
#  8 5 4
#  7 0 3
#  2 6 1
#
#  8 5 4
#  0 2 3
#  6 7 1
#
#  0 5 4
#  8 2 3
#  6 7 1
#
#  5 0 4
#  8 2 3
#  6 7 1
#
#  5 2 4
#  8 0 3
#  6 7 1
#
#  5 4 0
#  8 2 3
#  6 7 1
#
#  8 0 4
#  2 5 3
#  6 7 1
#
#  0 8 4
#  2 5 3
#  6 7 1
#
#  2 8 4
#  0 5 3
#  6 7 1
#
#  2 8 4
#  5 0 3
#  6 7 1
#
#  8 5 4
#  2 7 3
#  6 1 0
#
#  8 5 4
#  6 2 3
#  0 7 1
#
#  8 4 0
#  2 5 3
#  6 7 1
#
#  2 8 4
#  6 5 3
#  0 7 1
#
#  8 5 4
#  6 2 3
#  7 0 1
#
#  8 5 4
#  6 0 3
#  7 2 1
#
#  8 4 3
#  2 5 0
#  6 7 1
#
#  8 4 3
#  2 0 5
#  6 7 1
#
#  2 8 5
#  6 3 4
#  0 7 1
#
#  2 8 5
#  3 4 1
#  6 7 0
#
#  2 8 5
#  3 4 1
#  6 0 7
#
#  2 8 5
#  3 0 1
#  6 4 7
#
#  2 8 5
#  3 4 1
#  0 6 7
#
#  8 5 4
#  2 3 1
#  6 7 0
#
#  8 5 4
#  2 3 1
#  6 0 7
#
#  8 5 4
#  2 0 1
#  6 3 7
#
#  8 5 4
#  0 2 1
#  6 3 7
#
#  0 5 4
#  8 2 1
#  6 3 7
#
#  8 0 4
#  2 5 1
#  6 3 7
#
#  0 8 4
#  2 5 1
#  6 3 7
#
#  8 5 4
#  6 2 1
#  0 3 7
#
#  8 4 0
#  2 5 1
#  6 3 7
#
#  8 5 4
#  2 1 0
#  6 3 7
#
#  8 5 4
#  2 1 7
#  6 3 0
#
#  8 5 0
#  2 1 4
#  6 3 7
#
#  8 5 4
#  2 3 1
#  0 6 7
#
#  8 5 4
#  0 3 1
#  2 6 7
#
#  8 5 4
#  3 0 1
#  2 6 7
#
#  0 5 4
#  8 3 1
#  2 6 7
#
#  8 5 4
#  6 2 3
#  7 1 0
#
#  8 4 3
#  2 5 1
#  6 7 0
#
#  8 3 5
#  0 2 4
#  6 7 1
#
#  0 3 5
#  8 2 4
#  6 7 1
#
#  3 0 5
#  8 2 4
#  6 7 1
#
#  3 5 0
#  8 2 4
#  6 7 1
#
#  3 5 4
#  8 2 0
#  6 7 1
#
#  3 5 4
#  8 0 2
#  6 7 1
#
#  3 5 4
#  8 7 2
#  6 0 1
#
#  3 5 4
#  8 7 2
#  0 6 1
#
#  3 5 4
#  0 8 2
#  6 7 1
#
#  0 5 4
#  3 8 2
#  6 7 1
#
#  3 0 4
#  8 5 2
#  6 7 1
#
#  0 3 4
#  8 5 2
#  6 7 1
#
#  3 5 4
#  8 7 2
#  6 1 0
#
#  3 5 4
#  6 8 2
#  0 7 1
#
#  3 4 0
#  8 5 2
#  6 7 1
#
#  3 5 4
#  8 2 1
#  6 7 0
#
#  3 5 4
#  8 2 1
#  6 0 7
#
#  3 5 4
#  8 0 1
#  6 2 7
#
#  3 5 4
#  8 2 1
#  0 6 7
#
#  2 8 5
#  6 3 4
#  7 0 1
#
#  2 8 5
#  6 0 4
#  7 3 1
#
#  2 8 5
#  0 6 4
#  7 3 1
#
#  0 8 5
#  2 6 4
#  7 3 1
#
#  2 8 5
#  7 6 4
#  0 3 1
#
#  2 0 5
#  6 8 4
#  7 3 1
#
#  0 2 5
#  6 8 4
#  7 3 1
#
#  2 5 0
#  6 8 4
#  7 3 1
#
#  2 8 5
#  6 4 0
#  7 3 1
#
#  2 8 0
#  6 4 5
#  7 3 1
#
#  2 8 5
#  6 4 1
#  7 3 0
#
#  8 3 5
#  6 2 4
#  0 7 1
#
#  2 8 5
#  6 3 4
#  7 1 0
#
#  2 8 5
#  6 3 0
#  7 1 4
#
#  2 8 5
#  6 0 3
#  7 1 4
#
#  2 8 0
#  6 3 5
#  7 1 4
#
#  8 3 5
#  2 4 0
#  6 7 1
#
#  8 3 0
#  2 4 5
#  6 7 1
#
#  8 0 3
#  2 4 5
#  6 7 1
#
#  0 8 3
#  2 4 5
#  6 7 1
#
#  2 8 3
#  0 4 5
#  6 7 1
#
#  2 8 3
#  6 4 5
#  0 7 1
#
#  2 8 3
#  4 0 5
#  6 7 1
#
#  2 8 3
#  4 7 5
#  6 0 1
#
#  2 8 3
#  4 7 5
#  0 6 1
#
#  2 0 3
#  4 8 5
#  6 7 1
#
#  2 3 0
#  4 8 5
#  6 7 1
#
#  0 2 3
#  4 8 5
#  6 7 1
#
#  2 8 3
#  4 7 5
#  6 1 0
#
#  8 3 5
#  6 2 4
#  7 0 1
#
#  8 3 5
#  6 0 4
#  7 2 1
#
#  8 0 5
#  6 3 4
#  7 2 1
#
#  0 8 5
#  6 3 4
#  7 2 1
#
#  6 8 5
#  0 3 4
#  7 2 1
#
#  6 8 5
#  7 3 4
#  0 2 1
#
#  6 8 5
#  3 0 4
#  7 2 1
#
#  8 5 0
#  6 3 4
#  7 2 1
#
#  8 5 4
#  6 3 0
#  7 2 1
#
#  8 5 4
#  6 3 1
#  7 2 0
#
#  8 3 5
#  0 6 4
#  7 2 1
#
#  8 3 5
#  7 6 4
#  0 2 1
#
#  8 3 5
#  7 6 4
#  2 0 1
#
#  8 3 5
#  7 0 4
#  2 6 1
#
#  0 3 5
#  8 6 4
#  7 2 1
#
#  3 0 5
#  8 6 4
#  7 2 1
#
#  3 6 5
#  8 0 4
#  7 2 1
#
#  8 3 5
#  7 6 4
#  2 1 0
#
#  3 5 0
#  8 6 4
#  7 2 1
#
#  8 3 5
#  6 4 0
#  7 2 1
#
#  8 3 0
#  6 4 5
#  7 2 1
#
#  8 0 3
#  6 4 5
#  7 2 1
#
#  8 4 3
#  6 0 5
#  7 2 1
#
#  0 8 3
#  6 4 5
#  7 2 1
#
#  8 3 5
#  6 4 1
#  7 2 0
#
#  8 3 5
#  6 4 1
#  7 0 2
#
#  8 3 5
#  6 4 1
#  0 7 2
#
#  8 3 5
#  6 0 1
#  7 4 2
#
#  2 8 3
#  6 4 5
#  7 0 1
#
#  2 8 3
#  6 0 5
#  7 4 1
#
#  2 8 3
#  4 5 0
#  6 7 1
#
#  2 8 0
#  4 5 3
#  6 7 1
#
#  8 3 5
#  7 0 4
#  2 6 1
#
#  8 0 5
#  7 3 4
#  2 6 1
#
#  0 8 5
#  7 3 4
#  2 6 1
#
#  7 8 5
#  0 3 4
#  2 6 1
#
#  7 8 5
#  3 0 4
#  2 6 1
#
#  7 0 5
#  3 8 4
#  2 6 1
#
#  7 5 0
#  3 8 4
#  2 6 1
#
#  7 5 4
#  3 8 0
#  2 6 1
#
#  7 5 4
#  3 0 8
#  2 6 1
#
#  7 5 4
#  0 3 8
#  2 6 1
#
#  0 5 4
#  7 3 8
#  2 6 1
#
#  7 0 4
#  3 5 8
#  2 6 1
#
#  0 7 4
#  3 5 8
#  2 6 1
#
#  7 5 4
#  2 3 8
#  0 6 1
#
#  7 4 0
#  3 5 8
#  2 6 1
#
#  7 5 4
#  3 6 8
#  2 0 1
#
#  7 5 4
#  3 6 8
#  0 2 1
#
#  7 5 4
#  3 6 8
#  2 1 0
#
#  7 5 4
#  3 8 1
#  2 6 0
#
#  7 5 4
#  3 8 1
#  2 0 6
#
#  7 5 4
#  3 8 1
#  0 2 6
#
#  7 5 4
#  3 0 1
#  2 8 6
#
#  7 8 5
#  3 6 4
#  2 0 1
#
#  7 8 5
#  3 6 4
#  0 2 1
#
#  7 8 5
#  0 6 4
#  3 2 1
#
#  7 8 5
#  6 0 4
#  3 2 1
#
#  7 0 5
#  6 8 4
#  3 2 1
#
#  0 7 5
#  6 8 4
#  3 2 1
#
#  0 8 5
#  7 6 4
#  3 2 1
#
#  8 0 5
#  7 6 4
#  3 2 1
#
#  8 6 5
#  7 0 4
#  3 2 1
#
#  7 5 0
#  6 8 4
#  3 2 1
#
#  8 5 0
#  7 6 4
#  3 2 1
#
#  7 8 5
#  6 2 4
#  3 0 1
#
#  7 8 5
#  6 2 4
#  0 3 1
#
#  7 8 5
#  6 4 0
#  3 2 1
#
#  7 8 0
#  6 4 5
#  3 2 1
#
#  7 8 5
#  6 2 4
#  3 1 0
#
#  7 8 5
#  6 4 1
#  3 2 0
#
#  7 8 5
#  3 4 0
#  2 6 1
#
#  7 8 0
#  3 4 5
#  2 6 1
#
#  7 0 8
#  3 4 5
#  2 6 1
#
#  0 7 8
#  3 4 5
#  2 6 1
#
#  3 7 8
#  0 4 5
#  2 6 1
#
#  7 4 8
#  3 0 5
#  2 6 1
#
#  7 4 8
#  0 3 5
#  2 6 1
#
#  0 4 8
#  7 3 5
#  2 6 1
#
#  3 7 8
#  4 0 5
#  2 6 1
#
#  7 4 8
#  2 3 5
#  0 6 1
#
#  7 4 8
#  3 6 5
#  2 0 1
#
#  7 4 8
#  3 6 5
#  0 2 1
#
#  7 4 8
#  3 5 0
#  2 6 1
#
#  7 4 8
#  3 6 5
#  2 1 0
#
#  7 4 8
#  3 5 1
#  2 6 0
#
#  7 8 5
#  2 3 4
#  0 6 1
#
#  7 8 5
#  2 3 4
#  6 0 1
#
#  7 8 5
#  2 0 4
#  6 3 1
#
#  7 8 5
#  0 2 4
#  6 3 1
#
#  0 8 5
#  7 2 4
#  6 3 1
#
#  8 0 5
#  7 2 4
#  6 3 1
#
#  8 2 5
#  7 0 4
#  6 3 1
#
#  8 5 0
#  7 2 4
#  6 3 1
#
#  7 0 5
#  2 8 4
#  6 3 1
#
#  0 7 5
#  2 8 4
#  6 3 1
#
#  2 7 5
#  0 8 4
#  6 3 1
#
#  2 7 5
#  8 0 4
#  6 3 1
#
#  2 7 5
#  6 8 4
#  0 3 1
#
#  7 5 0
#  2 8 4
#  6 3 1
#
#  7 5 4
#  2 8 0
#  6 3 1
#
# ...
#  7 2 1
#
#  5 8 3
#  2 4 0
#  6 7 1
#
#  5 8 3
#  2 0 4
#  6 7 1
#
#  5 4 8
#  7 0 3
#  2 6 1
#
#  5 4 8
#  7 3 0
#  2 6 1
#
#  5 4 0
#  7 3 8
#  2 6 1
#
#  5 0 4
#  7 3 8
#  2 6 1
#
#  5 3 4
#  7 0 8
#  2 6 1
#
#  5 3 4
#  0 7 8
#  2 6 1
#
#  0 3 4
#  5 7 8
#  2 6 1
#
#  5 3 4
#  2 7 8
#  0 6 1
#
#  5 3 4
#  7 6 8
#  2 0 1
#
#  5 3 4
#  7 6 8
#  0 2 1
#
#  5 3 4
#  7 8 0
#  2 6 1
#
#  5 3 0
#  7 8 4
#  2 6 1
#
#  5 3 4
#  7 6 8
#  2 1 0
#
#  5 3 4
#  7 8 1
#  2 6 0
#
#  5 0 8
#  7 4 3
#  2 6 1
#
#  0 5 8
#  7 4 3
#  2 6 1
#
#  7 5 8
#  0 4 3
#  2 6 1
#
#  7 5 8
#  2 4 3
#  0 6 1
#
#  7 5 8
#  2 4 3
#  6 0 1
#
#  7 5 8
#  2 0 3
#  6 4 1
#
#  7 5 8
#  2 4 3
#  6 1 0
#
#  5 4 8
#  2 7 3
#  6 1 0
#
#  5 4 8
#  2 7 0
#  6 1 3
#
#  5 4 8
#  2 0 7
#  6 1 3
#
#  5 4 8
#  0 2 7
#  6 1 3
#
#  0 4 8
#  5 2 7
#  6 1 3
#
#  5 0 8
#  2 4 7
#  6 1 3
#
#  0 5 8
#  2 4 7
#  6 1 3
#
#  5 4 8
#  6 2 7
#  0 1 3
#
#  5 8 0
#  2 4 7
#  6 1 3
#
#  5 4 8
#  2 1 7
#  6 0 3
#
#  5 4 8
#  2 1 7
#  6 3 0
#
#  5 4 8
#  2 1 7
#  0 6 3
#
#  5 4 0
#  2 7 8
#  6 1 3
#
#  5 0 4
#  2 7 8
#  6 1 3
#
#  5 7 4
#  2 0 8
#  6 1 3
#
#  0 5 4
#  2 7 8
#  6 1 3
#
#  5 4 8
#  6 2 3
#  7 1 0
#
#  5 8 3
#  2 4 1
#  6 7 0
#
#  5 4 8
#  7 3 1
#  2 6 0
#
#  5 4 8
#  7 3 1
#  2 0 6
#
#  5 4 8
#  7 0 1
#  2 3 6
#
#  5 4 8
#  0 7 1
#  2 3 6
#
#  0 4 8
#  5 7 1
#  2 3 6
#
#  5 4 8
#  2 7 1
#  0 3 6
#
#  5 0 8
#  7 4 1
#  2 3 6
#
#  0 5 8
#  7 4 1
#  2 3 6
#
#  5 8 0
#  7 4 1
#  2 3 6
#
#  5 4 8
#  7 1 0
#  2 3 6
#
#  5 4 0
#  7 1 8
#  2 3 6
#
#  5 4 8
#  7 3 1
#  0 2 6
#
#  5 4 8
#  0 3 1
#  7 2 6
#
#  5 4 8
#  3 0 1
#  7 2 6
#
#  0 4 8
#  5 3 1
#  7 2 6
#
#  5 4 8
#  7 1 6
#  2 3 0
#
#  5 8 0
#  7 4 3
#  2 6 1
#
#  5 4 8
#  7 6 3
#  2 0 1
#
#  5 4 8
#  7 6 3
#  0 2 1
#
#  5 4 8
#  0 6 3
#  7 2 1
#
#  0 4 8
#  5 6 3
#  7 2 1
#
#  4 0 8
#  5 6 3
#  7 2 1
#
#  4 6 8
#  5 0 3
#  7 2 1
#
#  4 8 0
#  5 6 3
#  7 2 1
#
#  5 8 3
#  7 4 0
#  2 6 1
#
#  5 8 3
#  7 0 4
#  2 6 1
#
#  5 8 3
#  0 7 4
#  2 6 1
#
#  0 8 3
#  5 7 4
#  2 6 1
#
#  5 8 3
#  2 7 4
#  0 6 1
#
#  5 0 3
#  7 8 4
#  2 6 1
#
#  0 5 3
#  7 8 4
#  2 6 1
#
#  5 8 3
#  7 6 4
#  2 0 1
#
#  5 8 3
#  7 6 4
#  0 2 1
#
#  5 8 3
#  7 6 4
#  2 1 0
#
#  5 4 8
#  7 6 3
#  2 1 0
#
#  5 4 8
#  7 6 0
#  2 1 3
#
#  5 4 8
#  7 0 6
#  2 1 3
#
#  5 4 8
#  0 7 6
#  2 1 3
#
#  0 4 8
#  5 7 6
#  2 1 3
#
#  5 4 8
#  2 7 6
#  0 1 3
#
#  5 0 8
#  7 4 6
#  2 1 3
#
#  0 5 8
#  7 4 6
#  2 1 3
#
#  5 4 0
#  7 6 8
#  2 1 3
#
#  5 0 4
#  7 6 8
#  2 1 3
#
#  5 6 4
#  7 0 8
#  2 1 3
#
#  0 5 4
#  7 6 8
#  2 1 3
#
#  5 8 0
#  7 4 6
#  2 1 3
#
#  5 4 8
#  7 1 6
#  2 0 3
#
#  5 4 8
#  7 1 6
#  0 2 3
#
#  5 8 3
#  7 4 1
#  2 6 0
#
#  5 8 3
#  7 4 1
#  2 0 6
#
#  5 8 3
#  7 0 1
#  2 4 6
#
#  5 8 3
#  7 4 1
#  0 2 6
#
#  4 7 8
#  2 5 3
#  0 6 1
#
#  4 7 8
#  2 5 3
#  6 0 1
#
#  4 7 8
#  2 0 3
#  6 5 1
#
#  4 7 8
#  2 3 0
#  6 5 1
#
#  4 7 0
#  2 3 8
#  6 5 1
#
#  4 0 7
#  2 3 8
#  6 5 1
#
#  0 4 7
#  2 3 8
#  6 5 1
#
#  2 4 7
#  0 3 8
#  6 5 1
#
#  2 4 7
#  3 0 8
#  6 5 1
#
#  2 4 7
#  6 3 8
#  0 5 1
#
#  4 3 7
#  2 0 8
#  6 5 1
#
#  4 3 7
#  0 2 8
#  6 5 1
#
#  0 3 7
#  4 2 8
#  6 5 1
#
#  4 3 7
#  6 2 8
#  0 5 1
#
#  4 3 7
#  2 5 8
#  6 0 1
#
#  4 3 7
#  2 5 8
#  0 6 1
#
#  4 3 7
#  2 8 0
#  6 5 1
#
#  4 3 0
#  2 8 7
#  6 5 1
#
#  4 3 7
#  2 5 8
#  6 1 0
#
#  4 3 7
#  2 8 1
#  6 5 0
#
#  4 7 8
#  0 2 3
#  6 5 1
#
#  0 7 8
#  4 2 3
#  6 5 1
#
#  4 0 8
#  2 7 3
#  6 5 1
#
#  0 4 8
#  2 7 3
#  6 5 1
#
#  2 4 8
#  0 7 3
#  6 5 1
#
#  2 4 8
#  6 7 3
#  0 5 1
#
#  2 4 8
#  6 7 3
#  5 0 1
#
#  2 4 8
#  6 0 3
#  5 7 1
#
#  2 4 8
#  7 0 3
#  6 5 1
#
#  2 4 8
#  7 3 0
#  6 5 1
#
#  2 4 0
#  7 3 8
#  6 5 1
#
#  2 0 8
#  7 4 3
#  6 5 1
#
#  0 2 8
#  7 4 3
#  6 5 1
#
#  2 4 8
#  6 7 3
#  5 1 0
#
#  2 4 8
#  7 3 1
#  6 5 0
#
#  2 8 0
#  7 4 3
#  6 5 1
#
#  7 0 8
#  4 2 3
#  6 5 1
#
#  2 4 8
#  7 5 3
#  6 0 1
#
#  2 4 8
#  7 5 3
#  0 6 1
#
#  4 7 8
#  2 3 1
#  6 5 0
#
#  4 7 8
#  2 3 1
#  6 0 5
#
#  4 7 8
#  2 0 1
#  6 3 5
#
#  4 7 8
#  0 2 1
#  6 3 5
#
#  0 7 8
#  4 2 1
#  6 3 5
#
#  4 0 8
#  2 7 1
#  6 3 5
#
#  0 4 8
#  2 7 1
#  6 3 5
#
#  4 7 8
#  6 2 1
#  0 3 5
#
#  4 8 0
#  2 7 1
#  6 3 5
#
#  4 7 8
#  2 1 0
#  6 3 5
#
#  4 7 0
#  2 1 8
#  6 3 5
#
#  4 7 8
#  2 3 1
#  0 6 5
#
#  4 7 8
#  0 3 1
#  2 6 5
#
#  4 7 8
#  3 0 1
#  2 6 5
#
#  0 7 8
#  4 3 1
#  2 6 5
#
#  4 7 8
#  2 1 5
#  6 3 0
#
#  4 7 8
#  6 2 3
#  0 5 1
#
#  4 7 8
#  6 2 3
#  5 0 1
#
#  4 7 8
#  6 0 3
#  5 2 1
#
#  4 7 8
#  6 3 0
#  5 2 1
#
#  4 7 0
#  6 3 8
#  5 2 1
#
#  4 7 8
#  0 6 3
#  5 2 1
#
#  0 7 8
#  4 6 3
#  5 2 1
#
#  4 0 8
#  6 7 3
#  5 2 1
#
#  0 4 8
#  6 7 3
#  5 2 1
#
#  4 7 8
#  6 3 1
#  5 2 0
#
#  4 7 8
#  5 6 3
#  0 2 1
#
#  4 8 0
#  6 7 3
#  5 2 1
#
#  4 8 0
#  2 7 3
#  6 5 1
#
#  7 2 8
#  4 0 3
#  6 5 1
#
#  7 2 8
#  0 4 3
#  6 5 1
#
#  7 2 8
#  6 4 3
#  0 5 1
#
#  7 2 8
#  4 3 0
#  6 5 1
#
#  7 2 0
#  4 3 8
#  6 5 1
#
#  7 8 0
#  4 2 3
#  6 5 1
#
#  2 4 8
#  7 5 3
#  6 1 0
#
#  4 7 8
#  6 2 3
#  5 1 0
#
#  4 7 8
#  6 2 0
#  5 1 3
#
#  4 7 8
#  6 0 2
#  5 1 3
#
#  4 7 0
#  6 2 8
#  5 1 3
#
#  7 2 8
#  4 3 1
#  6 5 0
#
#  4 8 3
#  2 7 0
#  6 5 1
#
#  4 8 3
#  2 0 7
#  6 5 1
#
#  4 8 3
#  0 2 7
#  6 5 1
#
#  0 8 3
#  4 2 7
#  6 5 1
#
#  4 0 3
#  2 8 7
#  6 5 1
#
#  0 4 3
#  2 8 7
#  6 5 1
#
#  4 8 3
#  6 2 7
#  0 5 1
#
#  4 8 3
#  2 5 7
#  6 0 1
#
#  4 8 3
#  2 5 7
#  0 6 1
#
#  4 8 3
#  2 5 7
#  6 1 0
#
#  7 2 8
#  4 5 3
#  6 0 1
#
#  7 2 8
#  4 5 3
#  0 6 1
#
#  7 8 3
#  4 2 0
#  6 5 1
#
#  7 8 3
#  4 0 2
#  6 5 1
#
#  4 8 3
#  2 7 1
#  6 5 0
#
#  4 8 3
#  2 7 1
#  6 0 5
#
#  4 8 3
#  2 7 1
#  0 6 5
#
#  4 8 3
#  2 0 1
#  6 7 5
#
#  7 2 8
#  4 5 3
#  6 1 0
#
#  7 8 3
#  4 2 1
#  6 5 0
#
#  4 8 0
#  5 7 3
#  2 6 1
#
#  4 7 8
#  2 5 3
#  6 1 0
#
#  4 7 8
#  2 5 0
#  6 1 3
#
#  4 7 8
#  2 0 5
#  6 1 3
#
#  4 7 8
#  0 2 5
#  6 1 3
#
#  0 7 8
#  4 2 5
#  6 1 3
#
#  4 0 8
#  2 7 5
#  6 1 3
#
#  0 4 8
#  2 7 5
#  6 1 3
#
#  2 4 8
#  0 7 5
#  6 1 3
#
#  2 4 8
#  6 7 5
#  0 1 3
#
#  2 4 8
#  7 0 5
#  6 1 3
#
#  7 0 8
#  4 2 5
#  6 1 3
#
#  4 7 8
#  6 2 5
#  0 1 3
#
#  4 8 0
#  2 7 5
#  6 1 3
#
#  4 8 5
#  2 7 0
#  6 1 3
#
#  4 8 5
#  2 0 7
#  6 1 3
#
#  7 2 8
#  4 0 5
#  6 1 3
#
#  7 8 0
#  4 2 5
#  6 1 3
#
#  4 8 5
#  2 7 3
#  6 1 0
#
#  4 7 8
#  2 1 5
#  6 0 3
#
#  4 7 8
#  2 1 5
#  0 6 3
#
#  4 7 8
#  0 1 5
#  2 6 3
#
#  0 7 8
#  4 1 5
#  2 6 3
#
#  4 7 8
#  1 0 5
#  2 6 3
#
#  4 7 8
#  6 2 5
#  1 0 3
#
#  4 7 8
#  6 0 5
#  1 2 3
#
#  4 7 8
#  6 2 5
#  1 3 0
#
#  4 7 0
#  2 5 8
#  6 1 3
#
#  4 0 7
#  2 5 8
#  6 1 3
#
#  0 4 7
#  2 5 8
#  6 1 3
#
#  2 4 7
#  0 5 8
#  6 1 3
#
#  2 4 7
#  5 0 8
#  6 1 3
#
#  4 5 7
#  2 0 8
#  6 1 3
#
#  4 5 7
#  0 2 8
#  6 1 3
#
#  0 5 7
#  4 2 8
#  6 1 3
#
#  2 4 7
#  6 5 8
#  0 1 3
#
#  4 5 7
#  6 2 8
#  0 1 3
#
#  4 5 7
#  2 1 8
#  6 0 3
#
#  4 5 7
#  2 1 8
#  6 3 0
#
#  4 5 7
#  2 1 8
#  0 6 3
#
#  4 5 7
#  2 8 0
#  6 1 3
#
#  4 5 0
#  2 8 7
#  6 1 3
#
#  4 5 7
#  2 8 3
#  6 1 0
#
#  4 7 8
#  5 6 3
#  2 0 1
#
#  4 8 3
#  5 7 0
#  2 6 1
#
#  4 8 3
#  5 0 7
#  2 6 1
#
#  4 8 3
#  0 5 7
#  2 6 1
#
#  4 0 3
#  5 8 7
#  2 6 1
#
#  0 4 3
#  5 8 7
#  2 6 1
#
#  5 4 3
#  0 8 7
#  2 6 1
#
#  5 4 3
#  8 0 7
#  2 6 1
#
#  5 0 3
#  8 4 7
#  2 6 1
#
#  5 3 0
#  8 4 7
#  2 6 1
#
#  0 5 3
#  8 4 7
#  2 6 1
#
#  5 4 3
#  8 6 7
#  2 0 1
#
#  5 4 3
#  8 6 7
#  0 2 1
#
#  5 4 3
#  8 7 0
#  2 6 1
#
#  5 4 0
#  8 7 3
#  2 6 1
#
#  5 4 3
#  2 8 7
#  0 6 1
#
#  5 4 3
#  2 8 7
#  6 0 1
#
#  5 4 3
#  2 0 7
#  6 8 1
#
#  5 4 3
#  8 7 1
#  2 6 0
#
#  4 3 0
#  5 8 7
#  2 6 1
#
#  4 3 7
#  5 8 0
#  2 6 1
#
#  4 3 7
#  5 8 1
#  2 6 0
#
#  4 3 7
#  5 8 1
#  2 0 6
#
#  4 3 7
#  5 8 1
#  0 2 6
#
#  4 8 3
#  5 6 7
#  2 0 1
#
#  4 8 3
#  5 6 7
#  0 2 1
#
#  4 8 3
#  0 6 7
#  5 2 1
#
#  4 8 3
#  6 0 7
#  5 2 1
#
#  4 0 3
#  6 8 7
#  5 2 1
#
#  0 4 3
#  6 8 7
#  5 2 1
#
#  4 3 0
#  6 8 7
#  5 2 1
#
#  0 8 3
#  4 6 7
#  5 2 1
#
#  8 0 3
#  4 6 7
#  5 2 1
#
#  8 6 3
#  4 0 7
#  5 2 1
#
#  8 3 0
#  4 6 7
#  5 2 1
#
#  4 8 3
#  6 2 7
#  5 0 1
#
#  4 8 3
#  6 7 0
#  5 2 1
#
#  4 8 3
#  6 2 7
#  5 1 0
#
#  4 8 3
#  6 7 1
#  5 2 0
#
#  4 8 3
#  5 6 7
#  2 1 0
#
#  4 8 3
#  5 6 0
#  2 1 7
#
#  4 8 0
#  5 6 3
#  2 1 7
#
#  4 0 8
#  5 6 3
#  2 1 7
#
#  0 4 8
#  5 6 3
#  2 1 7
#
#  4 6 8
#  5 0 3
#  2 1 7
#
#  4 8 3
#  5 0 6
#  2 1 7
#
#  4 8 3
#  0 5 6
#  2 1 7
#
#  0 8 3
#  4 5 6
#  2 1 7
#
#  4 0 3
#  5 8 6
#  2 1 7
#
#  0 4 3
#  5 8 6
#  2 1 7
#
#  4 3 0
#  5 8 6
#  2 1 7
#
#  4 8 3
#  2 5 6
#  0 1 7
#
#  4 8 3
#  5 1 6
#  2 0 7
#
#  4 8 3
#  5 1 6
#  0 2 7
#
#  4 8 3
#  5 1 6
#  2 7 0
#
#  3 5 7
#  2 4 8
#  0 6 1
#
#  3 5 7
#  2 4 8
#  6 0 1
#
#  3 5 7
#  4 0 8
#  2 6 1
#
#  5 4 7
#  2 3 8
#  6 1 0
#
#  5 4 7
#  2 3 0
#  6 1 8
#
#  5 4 0
#  2 3 7
#  6 1 8
#
#  5 0 4
#  2 3 7
#  6 1 8
#
#  0 5 4
#  2 3 7
#  6 1 8
#
#  2 5 4
#  0 3 7
#  6 1 8
#
#  2 5 4
#  3 0 7
#  6 1 8
#
#  2 0 4
#  3 5 7
#  6 1 8
#
#  0 2 4
#  3 5 7
#  6 1 8
#
#  3 2 4
#  0 5 7
#  6 1 8
#
#  3 2 4
#  5 0 7
#  6 1 8
#
#  3 0 4
#  5 2 7
#  6 1 8
#
#  0 3 4
#  5 2 7
#  6 1 8
#
#  3 4 0
#  5 2 7
#  6 1 8
#
#  3 2 4
#  5 1 7
#  6 0 8
#
#  3 2 4
#  5 1 7
#  0 6 8
#
#  3 2 4
#  5 7 0
#  6 1 8
#
#  3 2 4
#  5 7 8
#  6 1 0
#
#  3 2 0
#  5 7 4
#  6 1 8
#
#  2 4 0
#  3 5 7
#  6 1 8
#
#  2 4 7
#  3 5 0
#  6 1 8
#
#  2 4 7
#  3 0 5
#  6 1 8
#
#  2 4 7
#  0 3 5
#  6 1 8
#
#  0 4 7
#  2 3 5
#  6 1 8
#
#  2 0 7
#  3 4 5
#  6 1 8
#
#  0 2 7
#  3 4 5
#  6 1 8
#
#  2 4 7
#  6 3 5
#  0 1 8
#
#  2 7 0
#  3 4 5
#  6 1 8
#
#  2 4 7
#  3 1 5
#  6 0 8
#
#  2 4 7
#  3 1 5
#  0 6 8
#
#  2 4 7
#  3 5 8
#  6 1 0
#
#  2 4 7
#  3 5 8
#  6 0 1
#
#  2 4 7
#  3 5 8
#  0 6 1
#
#  2 4 7
#  3 1 5
#  6 8 0
#
#  3 2 4
#  6 5 7
#  0 1 8
#
#  3 2 4
#  5 1 7
#  6 8 0
#
#  2 5 4
#  3 1 7
#  6 0 8
#
#  2 5 4
#  3 1 7
#  0 6 8
#
#  2 5 4
#  0 1 7
#  3 6 8
#
#  0 5 4
#  2 1 7
#  3 6 8
#
#  5 0 4
#  2 1 7
#  3 6 8
#
#  5 1 4
#  2 0 7
#  3 6 8
#
#  5 4 0
#  2 1 7
#  3 6 8
#
#  2 5 4
#  1 0 7
#  3 6 8
#
#  2 0 4
#  1 5 7
#  3 6 8
#
#  0 2 4
#  1 5 7
#  3 6 8
#
#  2 4 0
#  1 5 7
#  3 6 8
#
#  2 5 4
#  1 6 7
#  3 0 8
#
#  2 5 4
#  1 6 7
#  0 3 8
#
#  2 5 4
#  1 7 0
#  3 6 8
#
#  2 5 4
#  1 7 8
#  3 6 0
#
#  2 5 0
#  1 7 4
#  3 6 8
#
#  2 5 4
#  1 6 7
#  3 8 0
#
#  2 5 4
#  3 7 0
#  6 1 8
#
#  2 5 4
#  3 7 8
#  6 1 0
#
#  2 5 4
#  3 7 8
#  6 0 1
#
#  2 5 4
#  3 7 8
#  0 6 1
#
#  2 5 4
#  0 7 8
#  3 6 1
#
#  0 5 4
#  2 7 8
#  3 6 1
#
#  2 5 4
#  7 0 8
#  3 6 1
#
#  2 5 0
#  3 7 4
#  6 1 8
#
#  2 0 5
#  3 7 4
#  6 1 8
#
#  2 7 5
#  3 0 4
#  6 1 8
#
#  2 7 5
#  0 3 4
#  6 1 8
#
#  0 7 5
#  2 3 4
#  6 1 8
#
#  0 2 5
#  3 7 4
#  6 1 8
#
#  2 7 5
#  6 3 4
#  0 1 8
#
#  2 7 5
#  3 1 4
#  6 0 8
#
#  2 7 5
#  3 1 4
#  0 6 8
#
#  2 7 5
#  3 4 0
#  6 1 8
#
#  2 7 5
#  3 4 8
#  6 1 0
#
#  3 2 5
#  0 7 4
#  6 1 8
#
#  2 7 5
#  3 1 4
#  6 8 0
#
#  3 2 5
#  6 7 4
#  0 1 8
#
#  3 2 5
#  7 0 4
#  6 1 8
#
#  3 2 4
#  6 5 7
#  1 0 8
#
#  3 2 4
#  6 0 7
#  1 5 8
#
#  5 3 4
#  2 0 7
#  6 1 8
#
#  5 3 4
#  0 2 7
#  6 1 8
#
#  2 5 4
#  6 3 7
#  0 1 8
#
#  2 5 4
#  3 1 7
#  6 8 0
#
#  2 5 4
#  3 1 0
#  6 8 7
#
#  2 5 4
#  3 0 1
#  6 8 7
#
#  2 5 4
#  3 8 1
#  6 0 7
#
#  2 5 4
#  3 8 1
#  0 6 7
#
#  2 5 4
#  0 3 1
#  6 8 7
#
#  0 5 4
#  2 3 1
#  6 8 7
#
#  2 0 4
#  3 5 1
#  6 8 7
#
#  0 2 4
#  3 5 1
#  6 8 7
#
#  2 5 4
#  6 3 1
#  0 8 7
#
#  2 4 0
#  3 5 1
#  6 8 7
#
#  2 5 0
#  3 1 4
#  6 8 7
#
#  2 0 5
#  3 1 4
#  6 8 7
#
#  0 2 5
#  3 1 4
#  6 8 7
#
#  2 1 5
#  3 0 4
#  6 8 7
#
#  3 2 4
#  6 5 7
#  1 8 0
#
#  5 3 4
#  6 2 7
#  0 1 8
#
#  5 3 4
#  2 1 7
#  6 0 8
#
#  5 3 4
#  2 1 7
#  0 6 8
#
#  5 3 4
#  0 1 7
#  2 6 8
#
#  0 3 4
#  5 1 7
#  2 6 8
#
#  3 0 4
#  5 1 7
#  2 6 8
#
#  3 1 4
#  5 0 7
#  2 6 8
#
#  3 1 4
#  0 5 7
#  2 6 8
#
#  0 1 4
#  3 5 7
#  2 6 8
#
#  3 4 0
#  5 1 7
#  2 6 8
#
#  3 4 7
#  5 1 0
#  2 6 8
#
#  3 4 7
#  5 0 1
#  2 6 8
#
#  3 4 7
#  5 1 8
#  2 6 0
#
#  3 1 4
#  2 5 7
#  0 6 8
#
#  3 1 4
#  5 6 7
#  2 0 8
#
#  3 1 4
#  5 6 7
#  0 2 8
#
#  3 1 4
#  5 7 0
#  2 6 8
#
#  3 1 4
#  5 7 8
#  2 6 0
#
#  3 1 0
#  5 7 4
#  2 6 8
#
#  5 3 4
#  1 0 7
#  2 6 8
#
#  5 0 4
#  1 3 7
#  2 6 8
#
#  0 5 4
#  1 3 7
#  2 6 8
#
#  1 5 4
#  0 3 7
#  2 6 8
#
#  1 5 4
#  3 0 7
#  2 6 8
#
#  1 5 4
#  2 3 7
#  0 6 8
#
#  3 1 4
#  5 6 7
#  2 8 0
#
#  5 3 4
#  1 6 7
#  2 0 8
#
#  5 3 4
#  1 6 7
#  0 2 8
#
#  5 3 4
#  0 6 7
#  1 2 8
#
#  5 3 4
#  6 0 7
#  1 2 8
#
#  0 3 4
#  5 6 7
#  1 2 8
#
#  5 3 4
#  1 7 0
#  2 6 8
#
#  5 3 4
#  1 7 8
#  2 6 0
#
#  5 3 4
#  1 7 8
#  2 0 6
#
#  5 3 4
#  1 7 8
#  0 2 6
#
#  5 3 4
#  1 0 8
#  2 7 6
#
#  5 3 0
#  1 7 4
#  2 6 8
#
#  5 0 3
#  1 7 4
#  2 6 8
#
#  5 7 3
#  1 0 4
#  2 6 8
#
#  0 5 3
#  1 7 4
#  2 6 8
#
#  5 3 4
#  1 6 7
#  2 8 0
#
#  5 3 4
#  1 6 0
#  2 8 7
#
#  5 3 4
#  1 0 6
#  2 8 7
#
#  5 3 0
#  1 6 4
#  2 8 7
#
#  5 3 4
#  2 7 0
#  6 1 8
#
#  5 3 4
#  2 7 8
#  6 1 0
#
#  5 3 4
#  2 7 8
#  6 0 1
#
#  5 3 0
#  2 7 4
#  6 1 8
#
#  5 0 3
#  2 7 4
#  6 1 8
#
#  5 7 3
#  2 0 4
#  6 1 8
#
#  5 7 3
#  0 2 4
#  6 1 8
#
#  0 7 3
#  5 2 4
#  6 1 8
#
#  7 0 3
#  5 2 4
#  6 1 8
#
#  7 3 0
#  5 2 4
#  6 1 8
#
#  0 5 3
#  2 7 4
#  6 1 8
#
#  5 7 3
#  6 2 4
#  0 1 8
#
#  7 2 3
#  5 0 4
#  6 1 8
#
#  5 7 3
#  2 1 4
#  6 0 8
#
#  5 7 3
#  2 1 4
#  0 6 8
#
#  5 7 3
#  0 1 4
#  2 6 8
#
#  0 7 3
#  5 1 4
#  2 6 8
#
#  5 7 3
#  2 4 0
#  6 1 8
#
#  5 7 0
#  2 4 3
#  6 1 8
#
#  5 0 7
#  2 4 3
#  6 1 8
#
#  0 5 7
#  2 4 3
#  6 1 8
#
#  5 7 3
#  2 4 8
#  6 1 0
#
#  5 7 3
#  2 4 8
#  6 0 1
#
#  5 7 3
#  2 0 8
#  6 4 1
#
#  5 7 3
#  2 4 8
#  0 6 1
#
#  2 5 3
#  0 7 4
#  6 1 8
#
#  5 7 3
#  6 2 4
#  1 0 8
#
#  5 7 3
#  6 0 4
#  1 2 8
#
#  5 7 3
#  2 1 4
#  6 8 0
#
#  5 7 3
#  2 1 0
#  6 8 4
#
#  5 7 3
#  2 0 1
#  6 8 4
#
#  5 7 0
#  2 1 3
#  6 8 4
#
#  2 5 3
#  6 7 4
#  0 1 8
#
#  2 5 3
#  7 0 4
#  6 1 8
#
#  2 0 3
#  7 5 4
#  6 1 8
#
#  2 3 0
#  7 5 4
#  6 1 8
#
#  0 2 3
#  7 5 4
#  6 1 8
#
#  5 7 3
#  6 2 4
#  1 8 0
#
#  2 5 4
#  6 3 7
#  1 0 8
#
#  2 5 4
#  6 0 7
#  1 3 8
#
#  2 5 4
#  0 6 7
#  1 3 8
#
#  0 5 4
#  2 6 7
#  1 3 8
#
#  5 0 4
#  2 6 7
#  1 3 8
#
#  5 6 4
#  2 0 7
#  1 3 8
#
#  5 4 0
#  2 6 7
#  1 3 8
#
#  2 0 4
#  6 5 7
#  1 3 8
#
#  0 2 4
#  6 5 7
#  1 3 8
#
#  6 2 4
#  0 5 7
#  1 3 8
#
#  6 2 4
#  5 0 7
#  1 3 8
#
#  6 2 4
#  1 5 7
#  0 3 8
#
#  2 4 0
#  6 5 7
#  1 3 8
#
#  2 4 7
#  6 5 0
#  1 3 8
#
#  2 4 7
#  6 0 5
#  1 3 8
#
#  2 4 7
#  6 5 8
#  1 3 0
#
#  2 5 4
#  6 7 0
#  1 3 8
#
#  2 5 4
#  6 7 8
#  1 3 0
#
#  2 5 4
#  6 7 8
#  1 0 3
#
#  2 5 4
#  6 7 8
#  0 1 3
#
#  2 5 4
#  6 0 8
#  1 7 3
#
#  2 5 0
#  6 7 4
#  1 3 8
#
#  2 0 5
#  6 7 4
#  1 3 8
#
#  2 7 5
#  6 0 4
#  1 3 8
#
#  0 2 5
#  6 7 4
#  1 3 8
#
#  5 3 4
#  6 2 7
#  1 0 8
#
#  2 5 3
#  6 7 4
#  1 0 8
#
#  2 5 3
#  6 0 4
#  1 7 8
#
#  2 5 3
#  7 1 4
#  6 0 8
#
#  2 5 3
#  7 1 4
#  0 6 8
#
#  2 5 3
#  7 4 0
#  6 1 8
#
#  2 5 0
#  7 4 3
#  6 1 8
#
#  2 5 3
#  7 4 8
#  6 1 0
#
#  5 3 4
#  2 1 7
#  6 8 0
#
#  5 3 4
#  2 1 0
#  6 8 7
#
#  5 3 4
#  2 0 1
#  6 8 7
#
#  5 0 4
#  2 3 1
#  6 8 7
#
#  5 4 0
#  2 3 1
#  6 8 7
#
#  5 3 4
#  2 8 1
#  6 0 7
#
#  5 3 4
#  2 8 1
#  0 6 7
#
#  5 3 4
#  0 8 1
#  2 6 7
#
#  5 3 4
#  8 0 1
#  2 6 7
#
#  0 3 4
#  5 8 1
#  2 6 7
#
#  5 3 4
#  0 2 1
#  6 8 7
#
#  0 3 4
#  5 2 1
#  6 8 7
#
#  3 0 4
#  5 2 1
#  6 8 7
#
#  3 2 4
#  5 0 1
#  6 8 7
#
#  3 4 0
#  5 2 1
#  6 8 7
#
#  5 4 1
#  2 3 0
#  6 8 7
#
#  5 4 1
#  2 3 7
#  6 8 0
#
#  5 4 1
#  2 0 3
#  6 8 7
#
#  5 3 4
#  2 8 1
#  6 7 0
#
#  5 3 4
#  2 8 0
#  6 7 1
#
#  5 3 0
#  2 8 4
#  6 7 1
#
#  5 3 4
#  6 2 1
#  0 8 7
#
#  5 3 4
#  6 2 1
#  8 0 7
#
#  5 3 4
#  6 0 1
#  8 2 7
#
#  5 3 4
#  6 2 1
#  8 7 0
#
#  5 3 0
#  2 1 4
#  6 8 7
#
#  5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/1r/z755k3s139jfwmddvgtz126m0000gp/T/ipykernel_44608/3433407776.py in <module>
#      77     map = open.pop()
#      78     closed.append(map.map)
# ---> 79     print_map(map.map)
#      80     if map.age < 100:
#      81         child = map.move()
#
# /var/folders/1r/z755k3s139jfwmddvgtz126m0000gp/T/ipykernel_44608/3433407776.py in print_map(map)
#      62
#      63 def print_map(map):
# ---> 64     print("", map[0], map[1], map[2], "\n"
#      65         , map[3], map[4], map[5], "\n"
#      66         , map[6] , map[7] , map[8], "\n", "")
#
# ~/Library/Python/3.9/lib/python/site-packages/ipykernel/iostream.py in write(self, string)
#     517             is_child = (not self._is_master_process())
#     518             # only touch the buffer in the IO thread to avoid races
# --> 519             self.pub_thread.schedule(lambda: self._buffer.write(string))
#     520             if is_child:
#     521                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~/Library/Python/3.9/lib/python/site-packages/ipykernel/iostream.py in schedule(self, f)
#     212             self._events.append(f)
#     213             # wake event thread (message content is ignored)
# --> 214             self._event_pipe.send(b'')
#     215         else:
#     216             f()
#
# ~/Library/Python/3.9/lib/python/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     503                 )
#     504             data.group = group
# --> 505         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     506
#     507     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~/Library/Python/3.9/lib/python/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
